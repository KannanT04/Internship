# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Students Grade Prediction.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
print('The Shape of the dataset is :',df.shape)
# Out:
# The Shape of the dataset is : (571, 43)

# %%
print('The columns of the dataset are :',df.columns)
# Out:
# The columns of the dataset are : Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
print('The number of duplicates rows present in the dataset are :',df.duplicated().sum())
# Out:
# The number of duplicates rows present in the dataset are : 0

# %% [markdown]
# No duplicates presented in this dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 425

# %% [markdown]
# There are significant null values present in this dataset

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.replace(np.nan,0,inplace=True)
df.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# ...

# %%
cg=df.drop(['CS-403','CS-421','CS-406','CS-414','CS-419','CS-423','CS-412','MT-442','Seat No.'],axis=1)
cg
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
cg.dtypes
# Out:
# PH-121       float64
# HS-101       float64
# CY-105       float64
# HS-105/12    float64
# MT-111       float64
# CS-105       float64
# CS-106       float64
# EL-102       float64
# EE-119       float64
# ME-107       float64
# CS-107        object
# HS-205/20    float64
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217       float64
# CS-212       float64
# CS-215        object
# MT-331       float64
# EF-303       float64
# HS-304        object
# CS-301       float64
# CS-302       float64
# TC-383       float64
# EL-332       float64
# CS-318        object
# CS-306       float64
# CS-312        object
# CS-317       float64
# CGPA         float64
# dtype: object

# %%
categorical_cols=[]
for x in cg.dtypes.index:
    if cg.dtypes[x] == 'O':
        categorical_cols.append(x)
print('Object Data Type Columns are:\n', categorical_cols)

#getting the list of numeric data type column names
numerical_cols=[]
for x in cg.dtypes.index:
    if cg.dtypes[x] == 'float64' or cg.dtypes[x] == 'int64':
        numerical_cols.append(x)
print('Numerical Data Type Columns are:', numerical_cols)
# Out:
# Object Data Type Columns are:
#  ['CS-107', 'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'CS-215', 'HS-304', 'CS-318', 'CS-312']
# Numerical Data Type Columns are: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'HS-205/20', 'EE-217', 'CS-212', 'MT-331', 'EF-303', 'CS-301', 'CS-302', 'TC-383', 'EL-332', 'CS-306', 'CS-317', 'CGPA']

# %%
pd.unique(cg['PH-121'])
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
grades_enc={'B-':2.7, 'A':4, 'D':1.0, 'A-':3.7, 'B+':3.4, 'B':3.0, 'C+':2.4, 'C':2.0, 'C-':1.7, 'D+':1.4, 'WU':0.0, 'A+':4.4,'F':0.7}

# %%
input=cg.drop('CGPA',axis=1)
target=cg['CGPA']

# %%
for item in input:
    input[item]=input[item].replace(grades_enc)
input.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.4     1.4        1.0     1.0     3.7     1.4     1.7     1.0
# 4     3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107  ... EF-303  HS-304 CS-301 CS-302 TC-383 EL-332 CS-318 CS-306  \
# 0     1.7  ...    1.7     2.4    3.0    2.0    2.4    2.0    1.7    2.0
# 1     1.0  ...    1.0     1.7    3.7    1.4    1.7    2.0    3.7    1.0
# 2     3.7  ...    2.4       4    3.4    3.7    3.0    3.4    3.7    3.7
# 3     2.4  ...    1.0     2.7    1.0    2.7    1.4    1.4    3.4    1.7
# 4     3.7  ...    1.7     3.7    2.7    3.7    2.4    3.7    2.7    3.7
#
#   CS-312  CS-317
# 0    1.7     1.7
# 1    1.4     1.0
# ...

# %%
cg=pd.concat([input,target],axis=1)

# %%
cg.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.035026    2.632399    3.285639    2.904028    3.006655    3.359370
# std      0.986736    0.910167    0.950570    1.046415    0.967774    0.831483
# min      0.000000    0.700000    0.000000    0.000000    0.000000    1.000000
# 25%      2.400000    2.000000    2.700000    2.000000    2.400000    3.000000
# 50%      3.400000    2.700000    3.700000    3.000000    3.400000    3.700000
# 75%      3.700000    3.400000    4.000000    3.700000    3.700000    4.000000
# max      4.400000    4.400000    4.400000    4.400000    4.400000    4.400000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-212  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.966025    2.991419    3.024343    2.706655  ...    2.783012
# ...

# %%
cg.hist(bins=30,figsize=(30,15))
plt.show()

# %%
cg.skew()
# Out:
# PH-121      -0.798759
# HS-101      -0.186230
# CY-105      -1.296867
# HS-105/12   -0.495252
# MT-111      -0.748997
# CS-105      -1.121928
# CS-106      -0.967835
# EL-102      -0.745638
# EE-119      -0.825078
# ME-107      -0.347600
# HS-205/20   -1.668695
# EE-217      -1.080000
# CS-212      -0.694639
# MT-331      -0.892756
# EF-303      -0.542593
# CS-301      -0.753064
# CS-302      -1.213390
# TC-383      -0.587260
# EL-332      -0.731018
# CS-306      -0.820786
# CS-317      -0.474442
# CGPA        -0.497203
# dtype: float64

# %%
cg.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.408002  0.638184   0.561927  0.517067  0.674728
# HS-101     0.408002  1.000000  0.362841   0.489681  0.473487  0.445214
# CY-105     0.638184  0.362841  1.000000   0.594919  0.598734  0.624363
# HS-105/12  0.561927  0.489681  0.594919   1.000000  0.539199  0.551864
# MT-111     0.517067  0.473487  0.598734   0.539199  1.000000  0.458463
# CS-105     0.674728  0.445214  0.624363   0.551864  0.458463  1.000000
# CS-106     0.335319  0.373169  0.436825   0.546645  0.579246  0.331787
# EL-102     0.447568  0.387764  0.508296   0.389074  0.589668  0.384679
# EE-119     0.662714  0.327728  0.570440   0.480101  0.457297  0.605179
# ME-107     0.580128  0.369989  0.494379   0.394228  0.500506  0.500979
# HS-205/20  0.368069  0.221619  0.389975   0.267232  0.403825  0.249116
# EE-217     0.492377  0.386340  0.508971   0.437878  0.596693  0.425640
# ...

# %%
plt.figure(figsize=(30,30))
sns.heatmap(cg.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=cg.drop('CGPA',axis=1)
y=cg['CGPA']

# %%
x.shape
# Out:
# (571, 33)

# %%
y.shape
# Out:
# (571,)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR

# %%
maxAcc=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
        
print('Maximum r2 score is',maxAcc,' on Random State',maxRS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2272\2387244909.py in <module>
#       4     x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
#       5     lr=LinearRegression()
# ----> 6     lr.fit(x_train,y_train)
#       7     pred=lr.predict(x_test)
#       8     acc=r2_score(y_test,pred)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
