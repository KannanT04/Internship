# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import re
from selenium.webdriver.common.by import By

# %% [markdown]
# # Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page.

# %%
driver=webdriver.Chrome()

# %%
url1="https://www.flipkart.com/search?q=smartphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
driver.get(url1)

# %%
Brand_Name=[]
Colour=[]
Storage_RAM_ROM=[]
P_F_Camera=[]
Display_size_Resolution=[]
ProcessorAndCores=[]
Battery=[]
Price=[]
Product_URL=[]

# %%
BName=driver.find_elements(By.XPATH,"//div[@class='_4rR01T']")
for i in BName:
    if i.text is None :
        Brand_Name.append("--") 
    else:
        Brand_Name.append(i.text)
print(len(Brand_Name),Brand_Name)
# Out:
# 24 ['POCO C51 (Royal Blue, 64 GB)', 'vivo T2x 5G (Glimmer Black, 128 GB)', 'vivo T2x 5G (Marine Blue, 128 GB)', 'vivo T2x 5G (Aurora Gold, 128 GB)', 'vivo T2x 5G (Aurora Gold, 128 GB)', 'vivo T2x 5G (Marine Blue, 128 GB)', 'vivo T2x 5G (Glimmer Black, 128 GB)', 'vivo T2x 5G (Glimmer Black, 128 GB)', 'vivo T2x 5G (Marine Blue, 128 GB)', 'vivo T2x 5G (Aurora Gold, 128 GB)', 'Motorola G34 5G (Ice Blue, 128 GB)', 'Motorola G34 5G (Ocean Green, 128 GB)', 'Motorola G34 5G (Ocean Green, 128 GB)', 'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)', 'POCO C51 (Power Black, 64 GB)', 'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256 GB)', 'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128 GB)', 'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)', 'POCO C55 (Forest Green, 64 GB)', 'POCO C55 (Cool Blue, 128 GB)', 'POCO C55 (Power Black, 64 GB)', 'Motorola g54 5G (Pearl Blue, 128 GB)', 'Motorola G34 5G (Ice Blue, 128 GB)', 'REDMI 12 (Pastel Blue, 128 GB)']

# %%
ram=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[1]")
for i in ram:
    if i.text is None :
        Storage_RAM_ROM.append("--") 
    else:
        Storage_RAM_ROM.append(i.text)
print(len(Storage_RAM_ROM),Storage_RAM_ROM)
# Out:
# 24 ['4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '6 GB RAM | 128 GB ROM', '6 GB RAM | 128 GB ROM', '6 GB RAM | 128 GB ROM', '4 GB RAM | 128 GB ROM', '4 GB RAM | 128 GB ROM', '4 GB RAM | 128 GB ROM', '8 GB RAM | 128 GB ROM', '8 GB RAM | 128 GB ROM', '8 GB RAM | 128 GB ROM', '8 GB RAM | 128 GB ROM', '8 GB RAM | 128 GB ROM', '4 GB RAM | 128 GB ROM', '8 GB RAM | 256 GB ROM', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '8 GB RAM | 256 GB ROM', '8 GB RAM | 128 GB ROM', '8 GB RAM | 128 GB ROM', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 128 GB ROM', '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB']

# %%
PC=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[3]")
for i in PC:
    if i.text is None :
        P_F_Camera.append("--") 
    else:
        P_F_Camera.append(i.text)
print(len(P_F_Camera),P_F_Camera)
# Out:
# 24 ['8MP Dual Rear Camera | 5MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 8MP Front Camera', '50MP + 2MP | 16MP Front Camera', '50MP + 2MP | 16MP Front Camera', '50MP + 2MP | 16MP Front Camera', '108MP Rear Camera', '8MP Dual Rear Camera | 5MP Front Camera', '108MP Rear Camera', '108MP Rear Camera', '108MP Rear Camera', '50MP Dual Rear Camera | 5MP Front Camera', '50MP Dual Rear Camera | 5MP Front Camera', '50MP Dual Rear Camera | 5MP Front Camera', '50MP (OIS) + 8MP | 16MP Front Camera', '50MP + 2MP | 16MP Front Camera', '50MP + 8MP + 2MP | 8MP Front Camera']

# %%
DS=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[2]")
for i in DS:
    if i.text is None :
        Display_size_Resolution.append("--") 
    else:
        Display_size_Resolution.append(i.text)
print(len(Display_size_Resolution),Display_size_Resolution)
# Out:
# 24 ['16.56 cm (6.52 inch) HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.71 cm (6.58 inch) Full HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '17.07 cm (6.72 inch) Display', '16.56 cm (6.52 inch) HD+ Display', '17.07 cm (6.72 inch) Display', '17.07 cm (6.72 inch) Display', '17.07 cm (6.72 inch) Display', '17.04 cm (6.71 inch) HD+ Display', '17.04 cm (6.71 inch) HD+ Display', '17.04 cm (6.71 inch) HD+ Display', '16.51 cm (6.5 inch) Full HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '17.25 cm (6.79 inch) Full HD+ Display']

# %%
P=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[5]")
for i in P:
    if i.text is None :
        ProcessorAndCores.append("--") 
    else:
        ProcessorAndCores.append(i.text)
print(len(ProcessorAndCores),ProcessorAndCores)
# Out:
# 24 ['Helio G36 Processor', 'Dimensity 6020 Processor', 'Dimensity 6020 Processor', 'Dimensity 6020 Processor', 'Dimensity 6020 Processor', 'Dimensity 6020 Processor', 'Dimensity 6020 Processor', 'Dimensity 6020 Processor', 'Dimensity 6020 Processor', 'Dimensity 6020 Processor', 'Snapdragon 695 5G Processor', 'Snapdragon 695 5G Processor', 'Snapdragon 695 5G Processor', 'Domestic Warranty of 12 months on phone & 6 months on accessories', 'Helio G36 Processor', 'Domestic Warranty of 12 months on phone & 6 months on accessories', 'Domestic Warranty of 12 months on phone & 6 months on accessories', 'Domestic Warranty of 12 months on phone & 6 months on accessories', 'Mediatek Helio G85 Processor', 'Mediatek Helio G85 Processor', 'Mediatek Helio G85 Processor', 'Dimensity 7020 Processor', 'Snapdragon 695 5G Processor', 'Helio G88 Processor']

# %%
B=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[4]")
for i in B:
    if i.text is None :
        Battery.append("--") 
    else:
        Battery.append(i.text)
print(len(Battery),Battery)
# Out:
# 24 ['5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '6000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery']

# %%
price=driver.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']")
for i in price:
    if i.text is None :
        Price.append("--") 
    else:
        Price.append(i.text)
print(len(Price),Price)
# Out:
# 24 ['₹5,499', '₹12,999', '₹12,999', '₹12,999', '₹11,999', '₹11,999', '₹11,999', '₹14,999', '₹14,999', '₹14,999', '₹11,999', '₹11,999', '₹10,999', '₹20,972', '₹5,499', '₹20,845', '₹19,439', '₹19,469', '₹6,299', '₹7,299', '₹6,299', '₹13,999', '₹10,999', '₹10,499']

# %%
FlipKart=pd.DataFrame([])
FlipKart['Brand_Name']=Brand_Name
FlipKart['Storage_RAM_ROM']=Storage_RAM_ROM
FlipKart['Amount P_F_Camera']=P_F_Camera
FlipKart['Display_size_Resolution']=Display_size_Resolution
FlipKart['ProcessorAndCores']=ProcessorAndCores
FlipKart['Battery']=Battery
FlipKart['Price']=Price

FlipKart
# Out:
#                                            Brand_Name  \
# 0                        POCO C51 (Royal Blue, 64 GB)
# 1                 vivo T2x 5G (Glimmer Black, 128 GB)
# 2                   vivo T2x 5G (Marine Blue, 128 GB)
# 3                   vivo T2x 5G (Aurora Gold, 128 GB)
# 4                   vivo T2x 5G (Aurora Gold, 128 GB)
# 5                   vivo T2x 5G (Marine Blue, 128 GB)
# 6                 vivo T2x 5G (Glimmer Black, 128 GB)
# 7                 vivo T2x 5G (Glimmer Black, 128 GB)
# 8                   vivo T2x 5G (Marine Blue, 128 GB)
# 9                   vivo T2x 5G (Aurora Gold, 128 GB)
# 10                 Motorola G34 5G (Ice Blue, 128 GB)
# 11              Motorola G34 5G (Ocean Green, 128 GB)
# 12              Motorola G34 5G (Ocean Green, 128 GB)
# 13    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)
# 14                      POCO C51 (Power Black, 64 GB)
# 15  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...
# 16  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...
# 17    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)
# 18                     POCO C55 (Forest Green, 64 GB)
# 19                       POCO C55 (Cool Blue, 128 GB)
# 20                      POCO C55 (Power Black, 64 GB)
# 21               Motorola g54 5G (Pearl Blue, 128 GB)
# 22                 Motorola G34 5G (Ice Blue, 128 GB)
# 23                     REDMI 12 (Pastel Blue, 128 GB)
#
#                                  Storage_RAM_ROM  \
# 0    4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
# 1                          6 GB RAM | 128 GB ROM
# 2                          6 GB RAM | 128 GB ROM
# 3                          6 GB RAM | 128 GB ROM
# 4                          4 GB RAM | 128 GB ROM
# 5                          4 GB RAM | 128 GB ROM
# 6                          4 GB RAM | 128 GB ROM
# 7                          8 GB RAM | 128 GB ROM
# 8                          8 GB RAM | 128 GB ROM
# 9                          8 GB RAM | 128 GB ROM
# 10                         8 GB RAM | 128 GB ROM
# 11                         8 GB RAM | 128 GB ROM
# 12                         4 GB RAM | 128 GB ROM
# 13                         8 GB RAM | 256 GB ROM
# 14   4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
# 15                         8 GB RAM | 256 GB ROM
# 16                         8 GB RAM | 128 GB ROM
# 17                         8 GB RAM | 128 GB ROM
# 18   4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
# 19  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 20   4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
# 21  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 22                         4 GB RAM | 128 GB ROM
# 23  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB
#
#                            Amount P_F_Camera  \
# 0    8MP Dual Rear Camera | 5MP Front Camera
# 1              50MP + 2MP | 8MP Front Camera
# 2              50MP + 2MP | 8MP Front Camera
# 3              50MP + 2MP | 8MP Front Camera
# 4              50MP + 2MP | 8MP Front Camera
# 5              50MP + 2MP | 8MP Front Camera
# 6              50MP + 2MP | 8MP Front Camera
# 7              50MP + 2MP | 8MP Front Camera
# 8              50MP + 2MP | 8MP Front Camera
# 9              50MP + 2MP | 8MP Front Camera
# 10            50MP + 2MP | 16MP Front Camera
# 11            50MP + 2MP | 16MP Front Camera
# 12            50MP + 2MP | 16MP Front Camera
# 13                         108MP Rear Camera
# 14   8MP Dual Rear Camera | 5MP Front Camera
# 15                         108MP Rear Camera
# 16                         108MP Rear Camera
# 17                         108MP Rear Camera
# 18  50MP Dual Rear Camera | 5MP Front Camera
# 19  50MP Dual Rear Camera | 5MP Front Camera
# 20  50MP Dual Rear Camera | 5MP Front Camera
# 21      50MP (OIS) + 8MP | 16MP Front Camera
# 22            50MP + 2MP | 16MP Front Camera
# 23       50MP + 8MP + 2MP | 8MP Front Camera
#
#                   Display_size_Resolution  \
# 0        16.56 cm (6.52 inch) HD+ Display
# 1   16.71 cm (6.58 inch) Full HD+ Display
# 2   16.71 cm (6.58 inch) Full HD+ Display
# 3   16.71 cm (6.58 inch) Full HD+ Display
# 4   16.71 cm (6.58 inch) Full HD+ Display
# 5   16.71 cm (6.58 inch) Full HD+ Display
# 6   16.71 cm (6.58 inch) Full HD+ Display
# 7   16.71 cm (6.58 inch) Full HD+ Display
# 8   16.71 cm (6.58 inch) Full HD+ Display
# 9   16.71 cm (6.58 inch) Full HD+ Display
# 10        16.51 cm (6.5 inch) HD+ Display
# 11        16.51 cm (6.5 inch) HD+ Display
# 12        16.51 cm (6.5 inch) HD+ Display
# 13           17.07 cm (6.72 inch) Display
# 14       16.56 cm (6.52 inch) HD+ Display
# 15           17.07 cm (6.72 inch) Display
# 16           17.07 cm (6.72 inch) Display
# 17           17.07 cm (6.72 inch) Display
# 18       17.04 cm (6.71 inch) HD+ Display
# 19       17.04 cm (6.71 inch) HD+ Display
# 20       17.04 cm (6.71 inch) HD+ Display
# 21   16.51 cm (6.5 inch) Full HD+ Display
# 22        16.51 cm (6.5 inch) HD+ Display
# 23  17.25 cm (6.79 inch) Full HD+ Display
#
#                                     ProcessorAndCores           Battery  \
# 0                                 Helio G36 Processor  5000 mAh Battery
# 1                            Dimensity 6020 Processor  5000 mAh Battery
# 2                            Dimensity 6020 Processor  5000 mAh Battery
# 3                            Dimensity 6020 Processor  5000 mAh Battery
# 4                            Dimensity 6020 Processor  5000 mAh Battery
# 5                            Dimensity 6020 Processor  5000 mAh Battery
# 6                            Dimensity 6020 Processor  5000 mAh Battery
# 7                            Dimensity 6020 Processor  5000 mAh Battery
# 8                            Dimensity 6020 Processor  5000 mAh Battery
# 9                            Dimensity 6020 Processor  5000 mAh Battery
# 10                        Snapdragon 695 5G Processor  5000 mAh Battery
# 11                        Snapdragon 695 5G Processor  5000 mAh Battery
# 12                        Snapdragon 695 5G Processor  5000 mAh Battery
# 13  Domestic Warranty of 12 months on phone & 6 mo...  5000 mAh Battery
# 14                                Helio G36 Processor  5000 mAh Battery
# 15  Domestic Warranty of 12 months on phone & 6 mo...  5000 mAh Battery
# 16  Domestic Warranty of 12 months on phone & 6 mo...  5000 mAh Battery
# 17  Domestic Warranty of 12 months on phone & 6 mo...  5000 mAh Battery
# 18                       Mediatek Helio G85 Processor  5000 mAh Battery
# 19                       Mediatek Helio G85 Processor  5000 mAh Battery
# 20                       Mediatek Helio G85 Processor  5000 mAh Battery
# 21                           Dimensity 7020 Processor  6000 mAh Battery
# 22                        Snapdragon 695 5G Processor  5000 mAh Battery
# 23                                Helio G88 Processor  5000 mAh Battery
#
#       Price
# 0    ₹5,499
# 1   ₹12,999
# 2   ₹12,999
# 3   ₹12,999
# 4   ₹11,999
# 5   ₹11,999
# 6   ₹11,999
# 7   ₹14,999
# 8   ₹14,999
# 9   ₹14,999
# 10  ₹11,999
# 11  ₹11,999
# 12  ₹10,999
# 13  ₹20,972
# 14   ₹5,499
# 15  ₹20,845
# 16  ₹19,439
# 17  ₹19,469
# 18   ₹6,299
# 19   ₹7,299
# 20   ₹6,299
# 21  ₹13,999
# 22  ₹10,999
# 23  ₹10,499

# %%
FlipKart.to_csv('Flipkart.csv')

# %% [markdown]
# # Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome()
driver.get('https://www.hostelworld.com/')

# %%
location=driver.find_element(By.CLASS_NAME,"native-input")
location.send_keys('London, England')

# %%
search_button=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button[1]")
search_button.click()

# %%
Name=[]
Distance_From_City_Centre=[]
Ratings=[]
Total_Reviews=[]
Overall_Reviews=[]
Privates_From_Price=[]
Dorms_From_Price=[]
Facilities=[]
Property_Description=[]

# %%
Name_tags=driver.find_elements(By.XPATH,'//div[@class="property-name"]')
for i in Name_tags:
    Name.append(i.text)
Name[3:]
# Out:
# ["Wombat's City Hostel London",
#  'Palmers Lodge - Swiss Cottage',
#  "St Christopher's Village",
#  'NX London Hostel',
#  'Urbany Hostel London',
#  'Onefam Notting Hill',
#  'Generator London',
#  'Onefam Waterloo',
#  'Astor Hyde Park',
#  'Safestay London Elephant & Castle',
#  'Astor Museum Inn',
#  'No.8 Seven Sisters',
#  'No.8 Willesden Hostel London',
#  'Clink261',
#  'Smart Russell Square Hostel',
#  'Safestay London Kensington Holland Park',
#  'Smart Hyde Park Inn Hostel',
#  'Destinations Hostels @ The Gallery',
#  'Hostelle - women only hostel London',
#  'Queen Elizabeth Chelsea',
#  'Prime Backpackers Angel',
#  'Kabannas London St Pancras',
#  'London Backpackers',
#  'Smart Camden Inn Hostel',
#  'Astor Kensington',
#  "St Christopher's Hammersmith",
#  'Astor Victoria',
#  'Phoenix Hostel',
#  'Barmy Badger Backpackers',
#  'Park Villa']

# %%
distance_tags=driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
for i in distance_tags:
    Distance_From_City_Centre.append(i.text.replace(' - ',''))
Distance_From_City_Centre
# Out:
# ['- 3.6km from city centre',
#  '- 6.5km from city centre',
#  '- 1.8km from city centre',
#  '- 6.1km from city centre',
#  '- 5.4km from city centre',
#  '- 5.5km from city centre',
#  '- 3km from city centre',
#  '- 0.7km from city centre',
#  '- 4.3km from city centre',
#  '- 1.7km from city centre',
#  '- 2.2km from city centre',
#  '- 9km from city centre',
#  '- 10km from city centre',
#  '- 3.2km from city centre',
#  '- 2.6km from city centre',
#  '- 5.8km from city centre',
#  '- 5km from city centre',
#  '- 1.7km from city centre',
#  '- 5.1km from city centre',
#  '- 5.7km from city centre',
#  '- 3.6km from city centre',
#  '- 3.3km from city centre',
#  '- 11.9km from city centre',
#  '- 4.4km from city centre',
#  '- 4.9km from city centre',
#  '- 7.5km from city centre',
#  '- 1.8km from city centre',
#  '- 4.2km from city centre',
#  '- 5.5km from city centre',
#  '- 6.3km from city centre']

# %%
ratings_tags=driver.find_elements(By.XPATH,'//span[@class="number"]')
for i in ratings_tags:
    Ratings.append(i.text)
Ratings[3:]
# Out:
# ['9.1',
#  '8.8',
#  '7.8',
#  '8.9',
#  '9.5',
#  '9.6',
#  '7.5',
#  '9.6',
#  '8.2',
#  '7.2',
#  '8.3',
#  '7.7',
#  '7.2',
#  '7.9',
#  '7.6',
#  '7.0',
#  '7.8',
#  '9.1',
#  '8.8',
#  '7.5',
#  '8.5',
#  '8.2',
#  '8.1',
#  '8.3',
#  '8.6',
#  '7.7',
#  '7.3',
#  '6.3',
#  '9.1',
#  '9.3']

# %%
Total_Review=driver.find_elements(By.XPATH,'//div[@class="review"]')
for i in Total_Review:
    Total_Reviews.append(i.text)
Total_Reviews
# Out:
# ['(15901)',
#  '(15972)',
#  '(12873)',
#  '(2146)',
#  '(1125)',
#  '(2593)',
#  '(8082)',
#  '(135)',
#  '(12327)',
#  '(5278)',
#  '(9455)',
#  '(4178)',
#  '(5201)',
#  '(515)',
#  '(10207)',
#  '(1783)',
#  '(6800)',
#  '(317)',
#  '(116)',
#  '(3687)',
#  '(871)',
#  '(2977)',
#  '(4568)',
#  '(3143)',
#  '(6595)',
#  '(4389)',
#  '(15098)',
#  '(4624)',
#  '(2041)',
#  '(931)']

# %%
hotels=pd.DataFrame({'Name':Name[3:],'Distance_From_City_Centre':Distance_From_City_Centre,'Ratings':Ratings[3:],'Total_Reviews':Total_Reviews})
hotels
# Out:
#                                        Name  Distance_From_City_Centre  \
# 0               Wombat's City Hostel London   - 3.6km from city centre
# 1             Palmers Lodge - Swiss Cottage   - 6.5km from city centre
# 2                  St Christopher's Village   - 1.8km from city centre
# 3                          NX London Hostel   - 6.1km from city centre
# 4                      Urbany Hostel London   - 5.4km from city centre
# 5                       Onefam Notting Hill   - 5.5km from city centre
# 6                          Generator London     - 3km from city centre
# 7                           Onefam Waterloo   - 0.7km from city centre
# 8                           Astor Hyde Park   - 4.3km from city centre
# 9         Safestay London Elephant & Castle   - 1.7km from city centre
# 10                         Astor Museum Inn   - 2.2km from city centre
# 11                       No.8 Seven Sisters     - 9km from city centre
# 12             No.8 Willesden Hostel London    - 10km from city centre
# 13                                 Clink261   - 3.2km from city centre
# 14              Smart Russell Square Hostel   - 2.6km from city centre
# 15  Safestay London Kensington Holland Park   - 5.8km from city centre
# 16               Smart Hyde Park Inn Hostel     - 5km from city centre
# 17       Destinations Hostels @ The Gallery   - 1.7km from city centre
# 18      Hostelle - women only hostel London   - 5.1km from city centre
# 19                  Queen Elizabeth Chelsea   - 5.7km from city centre
# 20                  Prime Backpackers Angel   - 3.6km from city centre
# 21               Kabannas London St Pancras   - 3.3km from city centre
# 22                       London Backpackers  - 11.9km from city centre
# 23                  Smart Camden Inn Hostel   - 4.4km from city centre
# 24                         Astor Kensington   - 4.9km from city centre
# 25             St Christopher's Hammersmith   - 7.5km from city centre
# 26                           Astor Victoria   - 1.8km from city centre
# 27                           Phoenix Hostel   - 4.2km from city centre
# 28                 Barmy Badger Backpackers   - 5.5km from city centre
# 29                               Park Villa   - 6.3km from city centre
#
#    Ratings Total_Reviews
# 0      9.1       (15901)
# 1      8.8       (15972)
# 2      7.8       (12873)
# 3      8.9        (2146)
# 4      9.5        (1125)
# 5      9.6        (2593)
# 6      7.5        (8082)
# 7      9.6         (135)
# 8      8.2       (12327)
# 9      7.2        (5278)
# 10     8.3        (9455)
# 11     7.7        (4178)
# 12     7.2        (5201)
# 13     7.9         (515)
# 14     7.6       (10207)
# 15     7.0        (1783)
# 16     7.8        (6800)
# 17     9.1         (317)
# 18     8.8         (116)
# 19     7.5        (3687)
# 20     8.5         (871)
# 21     8.2        (2977)
# 22     8.1        (4568)
# 23     8.3        (3143)
# 24     8.6        (6595)
# 25     7.7        (4389)
# 26     7.3       (15098)
# 27     6.3        (4624)
# 28     9.1        (2041)
# 29     9.3         (931)

# %% [markdown]
# # Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver=webdriver.Chrome()
driver.get('https://www.youtube.com/watch?v=FzLpP8VBC6E')

# %%
Comments=[]
Upvotes=[]
Time=[]

# %%
scroll_pause_time = 2
scrolls = 50

for i in range(scrolls):
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(scroll_pause_time)

# %%
comments=driver.find_elements(By.XPATH,'//yt-formatted-string[@id="content-text"]')
for i in comments:
    Comments.append(i.text)
Comments[:500]
# Out:
# ['Everytime i travel by train i expect i will meet a girl like meghna , but  always i have to sit with uncles and auntys ',
#  'ഈ പടം റിലീസ് ആയിട്ട് 13 വർഷം കഴിഞ്ഞു, ഇപ്പോഴും ഈ പാട്ടിന്റെ feelings വേറെ ലെവൽ തന്നെ അണ്ണാ',
#  'அது எப்படி திமிங்கலம் ஒரு படத்துல எல்லா பாட்டும் அழகா இருக்க முடியுது...வாரணம் ஆயிரம்',
#  'ചുരുക്കം ചില പാട്ടുകൾ മാത്രമേ ആദ്യം കേൾക്കുമ്പോൾ കിട്ടുന്ന അതെ freshness പിന്നീട് ഒരിക്കൽ കേൾക്കുമ്പോഴും നിലനിർത്താറുള്ളു..13 വർഷം കഴിഞ്ഞ് കേൾക്കുമ്പോളും ആദ്യം കേട്ട ആദ്യ ഫീൽ ആണ് ഈ പാട്ട് ️.. Really magical composition.',
#  "Vaaranam Aayiram is not just a movie, it's an emotion..️",
#  '2024 laa yaralam indha song kekureenga attedence here ',
#  "I'm a vijay fan but love all Suriya songs.... Fvrt love from Kerala....... Evide full nammalanallo",
#  'ഈ പടം ഇറങ്ങിയിട്ട് 15വർഷം കഴിയുന്നു ഇപ്പഴും ഈ പാട്ടിന്റെ feelings ഒന്ന് വേറെ തന്നെയാ ️2024ലും കേൾക്കുന്നവർ ലൈക്ക് അടിക്ക് ',
#  'தாமரை அவர்களின் மிகவும் அற்புதமான தமிழ் வரிகள் ️ வாழ்க தமிழ் ️',
#  'Male : Nenjukul peidhidum\nMaamazhai neerukul\nMoozhgidum thamarai\nSattendru marudhu vaanilai',
#  "REST IN PEACE STEVE BRO     The man behind the nenjukkul peidhidum maamazhai song's soulful play is no more in this world. Your music is always with us ️",
#  'ഇത് വെറും ഒരു പാട്ടല്ല.. ഒരു തലമുറയുടെ അടയാളം ആണ് ',
#  'കേരളത്തിൽ ഏറ്റവും കൂടുതൽ ആരാധകർ ഉള്ള തമിഴ് റൊമാന്റിക് സോങ് ! ️\nSuriya - Meghna ! ️',
#  'ഈ സോങ് എത്ര കേട്ടാലും മതിവരില്ല.. Amazing voice..',
#  'Each line \nEach vocals \nEach tune \nEach minute details of this song',
#  '14 Years of vaaranam aaiyiram\nWhen ever I felt down I just remembered the dialogue "what ever happens in life, life has to move on...!" Motivational and best cinima dialogue I ever heared GVM ',
#  'Guitar ഒരു വികാരമാക്കിയ സിനിമ ',
#  'എന്നെ സൂര്യ ഫാൻ ആക്കിയ സിനിമ..... ഇപോഴും fav song ️ suriya ',
#  'ഒരുപക്ഷെ പാട്ടു കൊണ്ട് കിഴടക്കിയ ഒരേ ഒരു നടൻ അത് ഇദ്ദേഹം ആകാം ️',
#  '"Thookangalai thooki sendrai..Ekkangalai thoovi sendrai"..this song is pure bliss ️..Harris and Hariharan combo is always magical',
#  "If I look at Suriya's eyes I feel hypnotized....so much expression without saying a word....his eyes do all the talking",
#  '2020 kidsகளுக்கு தெரியாது நம்ம 2k kidsகளின் சூரியா எவ்வளவு இனிமையானவன் என்று.',
#  "Harris Jayaraj sir's best ever work!!",
#  '3:47 comparing 2008 music to 2022,\nI really loving 2008 magic \nAfter 14 years I guaranted in 14 years no songs will be feel like this. HJ ️',
#  "After watching this movie;\nKids : Learnt Guitar\nMen's : Joined Gym\nLegends : Joined Army",
#  'never got bored of listening to this masterpiece from 2008 Harris absolutely nailed it',
#  'Suriya won best actor national award. Missed then for vaaranam aayiram. Got now for Soorarai pottru ️',
#  'കുട്ടിക്കാലം മനോഹരമാക്കിയ പാട്ടുകളിൽ ഒന്ന്.. Nostalgic song️',
#  'Varanam aayiram, Ayan and Sillunu oru kadhal one of my favourites...',
#  'Nenjukul peidhidum\nMaamazhai neerukul\nMoozhgidum thamarai\nSattendru marudhu vaanilai',
#  'എനിക്ക് തോന്നുന്നു മലയാളികൾ ആകും ഈ സോങ്ങ് കുടുതൽ കേൾക്കുന്നത്..എവിടെ നമ്മടെ മലയാളിസ്\nകേറിവാടാ മക്കളെ...',
#  '2:40 that train + Harris music  + hariharan voice  = semma feel',
#  'HarijiiiSurya sirHarris sirMagic......',
#  '14 Years of Varanam Aayiram \nGood Combo of Surya+GVM+Harris Jayaraj ',
#  'Surya \nസൂര്യ പഴയ പാട്ടിൽ  എനിക്ക് ഒത്തിരി ഇഷ്ടമുള്ള  oru പാട്ട് ആണിത് \nI this song',
#  'From loverboy Surya in Vaaram Aayiram to Rolex Suriya in Vikram ..... Surya sir has come a long way...... The most versatile actor in South India.....️',
#  'ഈ ഗിറ്റാറും പിടിച്ചോണ്ട് അണ്ണൻ ഓടി വന്ന് കേറിയത് ജനലക്ഷങ്ങളുടെ  ഹൃദയത്തിലേക്ക് ആണ് എപ്പോ കേട്ടാലും അതെ ഫ്രഷ്\u200cനെസ്  നമ്മൾ മലയാളികളുടെ ദത്തു പുത്രൻ #സൂര്യ',
#  'ഇത്രേം ഫാൻസ്\u200c ഉള്ള അന്യഭാഷ സോങ് കേരളത്തിൽ വേറെ കാണില്ല️ what a beautiful creation by harris jayaraj️',
#  'காதல் என்னை கேட்கவில்லை கேட்டால் அது காதல் இல்லை',
#  'സൂര്യ അണ്ണൻ ️️️️',
#  'National award, ath annan ing eduthu️',
#  'ലവ് സോങ് എന്നൊക്കെ പറഞ്ഞാൽ ഇതാണ് \nഇജാതി വരികളും കേൾക്കുമ്പോ കിട്ടുന്ന ആ ഫീലും പറഞ്ഞു അറിയിക്കാൻ പറ്റില്ല  \nഇല്ലാത്ത കാമുകിയെ പോലും ഓർത്ത് പോവുന്നു ',
#  'ഫോൺ ഒന്നും ഇല്ലാത്ത സമയത്ത് Sun മ്യൂസിക്കിൽ കാത്തിരുന്ന song ,,uffff , ഒരു രക്ക്ഷയും ഇല്ല അണ്ണാ , romantic Hero',
#  'மீண்டும் ஒரு தடவை சூர்யா & ஹாரிஸ் ஜெராஜ் இணைய வேண்டும் \nBest song surya and harris jeraj ',
#  'എത്ര വർഷം കഴിഞ്ഞു എന്നാലും എന്നെ വേട്ടയാടുന്നു ഈ സോങ് ',
#  'The best tamil song that touched my heart️ love from Srilanka🇱🇰',
#  'Gautam Menon is the director who gives more importance to female leads . He portrays them in a elegant manner . His respect for woman is shown through his movie.....',
#  'என் வயது 36  16 வருட முன்பு  நடந்த காலேஜ் நிகழ்வுகள்  கண் முன் நிறுத்தினார் ஹரிஷ் ஜெயராஜ்',
#  'ഈ സിനിമ ഇറങ്ങി കഴിഞ്ഞപ്പോൾ കുറേപേർ  guitar പഠിക്കാൻ ഇറങ്ങി കുറേപേർ  gym  ഇൽ പോവാൻ തുടങ്ങി കുറേപേർ army ഇൽ ജോയിൻ ചെയ്യാൻ ഇറങ്ങി  ....  ഇതിന്റെ ഒരേഒരു കാരണം സൂര്യ  ',
#  'தாமரை அக்காவின் வரிகள் மற்றும் ஹாரிஸ் அண்ணாவின் இசை. இந்த பாடல் மிகவும் அருமையாக இருக்கிறது.',
#  '5:39 മിനുട്സ്, ഒരായിരം ഓർമ്മകൾ ',
#  'Hairharan is as smooth as one could get. Thanks Harris Jayaraj.',
#  'This movie has a special place in my heart, I lost my first love just minutes after she proposed me inside her car, then met with fatal accident. It was inexplicably devastating. And after 6 years my real love helped me get through that suffering in just seconds all by her hug and kiss filled with true love. ',
#  '15 years of Cult Classic Varanam Aayiram!! \nWho all are still listening to this song',
#  'തിരിച്ചു കിട്ടുമോ ഇതുപോലൊരു സൂര്യയെ... ഇത് പോലൊരു കാലത്തെ...  \nവാരണം ആയിരം... \n️',
#  'என்ன ஒரு அற்புதமான வரிகள்... என் தமிழ் மொழிக்கு நிகர் தமிழ் தான்..... அதிலும் சிம்மகுரலோன் உச்சரிப்பு .....என்னவோ ஒரு மாதிரி இருக்கு சொல்ல முடியவில்லை...',
#  'Watched this song in theatre... Mann absolute magic ',
#  'RIP Steve Vatz... Your guitar classic will be ever remembered with this song !!',
#  '2008 ഞാൻ ജനിച്ച വർഷം.. ആ വർഷം റിലീസായ മൂവി ഇപ്പോഴാണ് ഞാൻ കണ്ടത്. ആ സമയത്ത് teenagers നു കിട്ടിയ തീയേറ്റർ എക്സ്പീരിയൻസ് കിട്ടിയില്ലല്ലോ എന്ന് വിഷമം തോന്നി.ആ സമയത്തെ teenagers ആണ് ഏറ്റവും ലക്കി. എന്തോരം നല്ല സിനിമയാ അവർക്ക് ആസ്വദിക്കാൻ പറ്റിയത് ',
#  'Ufff evaroo oruu felll ',
#  'ന്റെ  പൊന്നോ ... സ്കൂൾ  വിട്ട്  വന്നിട്ട്  വൈകിട്ടു  കിരൺ  ടീവിയിൽ  ഈ  പട്ടു  കേൾക്കുന്ന ആ  ഒരു  നൊസ്റ്റു ',
#  'എന്റെ മനസ്സിൽ ഞാൻ നാഷണൽ    അവാർഡ് കൊടുത്ത നടൻ ',
#  'The masterpiece... This song never gets old... Ethana dhadava ketaalum bore adikkave maatingudhu... ️️️️',
#  'സൂപ്പർ ',
#  "I am deeply saddened to hear of Steeve Vatz's passing. The iconic guitar riff he played in this song has inspired countless musicians, including myself, to take up the guitar.",
#  'ഈ പാട്ട് ഇന്നും ',
#  'ഇത് സൂര്യ ആണ്  ഇയാൾ ഇങ്ങനെ ആണ്  എല്ലാം  ഒറിജിനാലിറ്റിയിലെ  ചെയ്യൂ \nഗജിനി, വരണമായിരം  ഇതൊക്കെ ആണ് ഇദ്ദേഹതൊടുള്ള  ഇഷ്ടം കൂട്ടിയ സിനിമകൾ',
#  'varanam ayiram its an ഇമോഷൻ ️',
#  'Awaiting for almost 14 years for a song which could match the soulful feel of this amazing composition from Harris..But not a single song even near yet..Ageless Melody ',
#  'ഇതു കാണുമ്പോൾ ഒരിക്കൽ കണ്ണൂർ to തിരുവനന്തപുരം ട്രെയിൻ യാത്രയിൽ ഇതേ Tea Shirt ഉം ഇട്ട് ഗിറ്റാറും കൈയിൽ പിടിച്ചു ബോഗി മാറി Tik tok ചെയ്യനായി നിന്നതും ചെക്കർ വന്നപ്പോൾ ഓടി തള്ളിയതും ഓർമ വരുന്നു..️',
#  'എവർഗ്രീൻ...',
#  'Can anyone beat this masterpiece? \nStole our hearts forever \nAll time fav song ',
#  'മലയാളി പിള്ളേർ ഇവിടെ  വന്ന് നീലം മുക്കി പോയെ.. ️️',
#  'Every song in vaaranam aayiram hits different',
#  'இசையின் புரட்சி - ஹாரிஸ் ஜெயராஜ் ',
#  'Vaaranam aayram\nSurya annan\nEnte daivameeeee annan oreeee pwoliacting aarkum annante ezhayalathu veran kazhiyilaaa',
#  'what a lovely song by Harris.. this total varanam aayiram album is still ruling my playlist.. what a gem of movie , singers, director, actors, music, directors, all the cast n crew.. ',
#  'മദ്യം, ഗഞ്ച.. etc പോലെ ചില songs ഉം ലഹരിയാണ്....',
#  'എത്ര സിംഗിൾ ആയി നടക്കും എന്നൊക്കെ പറഞ്ഞാലും ഈ സോങ്  കണ്ട ആർക്ക് ആയാലും ഒരു വട്ടം എങ്കിലും പ്രേമിക്കാൻ തോന്നിയിട്ടുണ്ടാവും ️\nസൂര്യ ചുമ്മാ ഒരു ഷോട്ടിലും ജീവിച്ചു പോകുന്നു ',
#  'Harris jayaraj and surya combo hits very hard. The best in k-town. This track was the number one in pan india level at that time even without any social media. ',
#  'Early 2k kids..... Memories....  Dvd player   kettu kettu erinnaa dhingal.....',
#  "Still It's",
#  'Sameera️️️️️',
#  'ഗൗതം മേനോൻ വെറുതെ അല്ലാ ഇൗ സിനിമ റീമേക്ക് ചെയ്യാൻ കൊടുക്കാത്തത്...അത്രയ്ക്ക് കിടിലൻ അഭിനയം ആണ് സൂര്യ....',
#  'Re-release in Big Screen made this song a pure bliss',
#  'கவிஞர் தாமரையின் அழகான தமிழ் வரிகள்',
#  'One of the best harris',
#  'Vaaram Aayiram ️',
#  'നാളെ വാരണം ആയിരം  മൂവിയുടെ 4K remasterd version നു വേണ്ടി കാത്തിരിക്കുന്നവർ ഉണ്ടോ?',
#  'Who is hearing after  block buster movie soorarai pottru.',
#  'This Song & BGM Remember My Childhood Golden Days  Ini Andha Days la Thirumpa Varaathu la ',
#  'Romba romba eshtam Surya annaaa',
#  'meghnave marakkave mudiyale',
#  'My Everloveing Crush Suriya️',
#  'Goutham Menon sir ',
#  'സൂര്യ ഇങ്ങേര് പൊളിയാണ്. അഭിനയിക്കുകയല്ല. ജീവിക്കുകയാണ്.',
#  '15 years of epic album ',
#  'Ennodu vaa veedu varaikkum ..en veetaipaar ennai pidukkum....nice lines',
#  'Iam addit intha song kuku',
#  'Hariharan magical voice ',
#  'Harris Jayaraj .....',
#  'രാത്രി നിലാവെട്ടത്ത് ആകാശം നോക്കി ഹെഡ്സെറ്റിൽ കേൾക്കണം.\nകൂടെ ഒരു മന്ദമാരുതൻ കൂടെ വന്നാൽ...\nയാ മോനേ',
#  'Dhinamum Oru 2 times ah vadhu Inga songs eh kettarraaa',
#  'The song which taught millions to make love.. Megna will always be a pain..',
#  'I am always surya fans. ...from andrapradesh',
#  'Hariharan sir so sweet voice',
#  "Varaanam Aayiram is not just a movie it's an emotion ️",
#  'Imagine sitting in a bus,window seat, sunset time, this song in earphones',
#  'വർഷം കഴിയുംതോറും വീര്യം കൂടുന്ന വീഞ്ഞുപോലെ ',
#  'Jayaraj Feel+ suriya️',
#  'Surya can kill with his eyes...',
#  'Harris Jayaraj uffff .. his voice ultimate',
#  'Harris jayaraj ',
#  'Actually surya deserves a national award for his mind blowing performance in this movie',
#  'அன்னைக்கு ஒரு கனவு இன்னைக்கு வரைக்கும் நாபகம் இருக்கு dad ️',
#  'Each and every frame was absolutely masterpiece  and is a bliss for both eyes and ears ',
#  'Gauthum vasudev fan from Kerala ',
#  'Hariharan sir voice ️ ️',
#  'Vera leval Harris thalaivar',
#  'ഒരു പടം കൊണ്ട് ,  ഒരു  പാട്ടു കൊണ്ട് \nഫാൻസിനെ ഉണ്ടാകാൻ സാധിച്ച നടനും സിനിമയും ️',
#  '1:49 soul of nenjukkul peythidum #meltingpoint ',
#  '4:21 true bliss transition of hariharan sir️',
#  'Thalaivan Harris Gem ',
#  'Cute Experience Suriya anna i love you ',
#  'penne un mel pizhai ️ Harris jeyaraj',
#  'ഇവിടെ എന്താ മലയാളികൾ മാത്രമേ ഒള്ള...സൂര്യ അണ്ണന്റെ ഫാൻസൊക്കെ  കേരളത്തിലാണ്  ഉള്ളത്.... ഞാനും ഒരു സൂര്യ അണ്ണന്റെ katta fan ആണ്suriya annante കമന്റ് box വരെ മലയാളികൾക് സ്വന്തം',
#  'Still this song is alive in most of the hearts ',
#  'I heard this song when I was doing my UG in Chennai on 2009 and still m listening this song...some old memories are attached with it... Miss Chennai and her too... Love to all',
#  '14 yrs',
#  'Daily night orangum munb ee song vannu kelkum\nOld memories orth karayum',
#  ' super song',
#  'Who is watching this song in 2019 ',
#  'Happy birthday Harris maams',
#  'Nto oru feel annu ee patu kelkumbol️️️ surya️️',
#  'Now its 14 yearsAwww this movie and their song....',
#  "I loves the dress code of this song it's very simple",
#  "Better than today's  AR Rahman songs....",
#  'Vaaranam Aayiram, Ayan & Sillunu Oru Kadhal was my Childhood ️',
#  'എന്റെ രോമങ്ങൾക്ക് ഇഷ്ടം ആണ് ഈ outstanding സോങ് എന്തോ ',
#  'സൂര്യ അണ്ണൻ ️',
#  'Suriya ',
#  'நடிப்பின் நாயகன் ',
#  'Spb sir voice altimate super padiirukaru',
#  'എന്നാ ഒരു ഫീലാ... ബസിലും ട്രെയിനിലും അത്പോലെ കിടക്കുമ്പോളും ഒക്കെ ഹെഡ്സെറ്റ് വെച്ച് ഈ പാട്ട് കേൾക്കുമ്പോൾ കിട്ടുനൊരു ഫീൽ ഉണ്ടല്ലോ..... ',
#  "Such a Heart' melting lyrics never got bored listening to this masterpiece \U0001fae0",
#  'ഞാൻ സിംഗിളാണ് എന്ന് പറഞ്ഞ പയ്യന്മാർക്ക് പ്രേമിക്കാൻ തോന്നിപ്പിച്ച പാട്ട്     ഒരു പാട്ടു കൊണ്ട് കീഴടക്കിയ മനുഷ്യൻ  ....',
#  'In the movie la irrukkura ella songs um super',
#  'actor surya beautiful sameera and music director harris jeyraj  what a combination',
#  'Indha movie music ku national award kuduthurukalamey da ',
#  'മലയാളികൾ ഇപ്പോഴും ഈ പാട്ടു കേൾക്കുന്നെങ്കിൽ എവിടെ ലൈക് ഇടൂ\nTamil pasankal like podu & 2019 watchers too ️️',
#  "90's memories ",
#  'Vaaranam Aayiram ️',
#  'Personal fav.️',
#  "Vaarnam aayiram ️ It's a emotion",
#  'Miss u swetha ',
#  'Mouna ragam\nAlaipayuthey\nVaranam aayiram\nSillunu oru kadhal',
#  'My fav Suriyahh...🇮🇳\nMy Best n fav Tamizh love songs...\nLove from Odisha',
#  'Ee oru padathinte feel ',
#  '15 years of varanam aayiram',
#  'HariHaran Voice  Amazing\nHarrisJayaraj Music \nThamarai \U0001fab7 Lyricist ️',
#  "I'm Suriya fan",
#  '2008 ൽ Suriya അണ്ണൻ ഈ Guitar പിടിച്ചുകൊണ്ടു ഓടികയറിയത് ജന ലക്ഷങ്ങളുടെ ഹൃദയത്തിലേക്ക് ആണ്',
#  'സൂര്യ മുത്താണ് മുത്ത് ',
#  'Miss u Harris ',
#  'தமிழுக்கு கிடைத்த அரிய பொக்கிஷம்    தாமரை',
#  'Best song ever listned supperb',
#  "GVM please make this type of movie's....",
#  'ഈ പടത്തിൽ സൂര്യക്ക് പകരം വെക്കാൻ  ഇന്ത്യൻ സിനിമയിൽ ഒരുത്തനും ഇല്ല....അത്രക്ക് അഭിനയം ആണ് അണ്ണൻ ഇതിൽ ....',
#  '40 പിള്ളേരെ പിടിച്ചു ഇടിച്ചു രക്ഷകൻ ആകണ്ട കാര്യം ഇവിടെ ഇല്ല കൊടുക്കുന്നെ റോൾ അത് കൃത്യം ആയി സ്ക്രീൻ  പുലർത്തും ഈ മുതൽ ',
#  '2022 ഇൽ കാണുന്നവർക്കു ലൈക്കാനുള്ള നൂൽ \n ഇപ്പോളും ഈ song കേട്ട് പ്രണയിക്കാൻ തോന്നുന്നു എങ്കിൽ \nഈ പാട്ടിന്റെ റേഞ്ച് ഒന്നു വേറെ തന്നെ.. ',
#  'Me hearing the chord progression other than music excellent ',
#  'நெஞ்சுக்குள் பெய்வது மாமழை மட்டும் அல்ல சினேகா! உன் நினைவுகளும் தன்! உன் நினைவுகள் நிரம்பியுள்ளது என் இதயத்தில்! அது காதலாகவும் கவிதையாகவும் உன்னை சேர்கிறது! ஐ லவ் யூ சினேகா ️ பூபதி ️',
#  "You just imagining you're crush and feel it ",
#  'Please upload 4k remastered tamil full movie ayan',
#  '12 വർഷം കഴിഞ്ഞിട്ടും ഞാൻ ഇപ്പോഴും കേൾക്കുന്നു.. ഇത്രയും നൊസ്റ്റാൾജിക് ആയിട്ടുള്ള സൊങ്  ഞാൻ കേട്ടിട്ടില്ല..',
#  'Suriya Annaaa ️',
#  'I could listen to this song whole day on repeat  i think this song is magical',
#  'Harris Jayaraj , ARR, GVP ,U1,Anirudh , vidyasagar,Ilayaraja,vijay antony ️️',
#  'All songs are good in this movie  who accepted this ?',
#  'ஒரு பாட்டு சொல்லிவிடும், அந்த மொழியின் அழகையும் அதன் ரசனையையும். எது அழகு? இசையின் அழகுக்கு மேலும்  அழகு சேர்க்கும் வகையில் இனிய சொற்களால் பூப்போல கோர்க்கப்பட்ட எம் மொழி தமிழே அழகு.',
#  'Evasdroping...',
#  'All time favourite ',
#  'My frist love pannum pothu daliy entha song tha Vibe ... ',
#  'Epic movie  ️️️️️',
#  'My love suriya ️ I Love love this character ️',
#  'Harris sir you are awesome',
#  'This one album is enough to prove who Harris Jeyaraj is ️️',
#  'നുമ്മ favourite പാട്ട് ',
#  "It's one of the beautiful song I have ever listen. Miss u",
#  '14 years',
#  'All Suriya songs... best tamil songs ',
#  'என்னோடு வா வீடு வரைக்கும் . என் வீட்டை பார் என்னை பிடிக்கும் ️️️',
#  'ഇദ്ദേഹത്തേക്കാൾ ഫാൻസ്\u200c കൂടുതലുള്ള ധാരാളം അഭിനേതാക്കൾ ഉണ്ടായിരിക്കാം റൊമാന്റിക് സീൻ  ഒക്കെ ഇങ്ങനെ നല്ല പക്കയായിട്ട് അഭിനയിച്ചു  നമ്മടെ ഉള്ളിലൊരു ഫീൽ തരാനുള്ള കഴിവുണ്ടല്ലോ അത് ഞാൻ സൂര്യയിൽ മാത്രേ കണ്ടിട്ടുള്ളു',
#  'Train la pogumpothu intha song kelunga semma feel   school love memories varum',
#  '2.02 (Bougainvillea) In 11th std botany book they had given Bougainvillea as the example for climbers.My botany sir told that Bougainvillea is a paper flower and they had compared her laugh with paper flower because it couldn\'t wither " \nThank you sir for teaching us by comparing lessons with mass media which we can easily understand and never forgot.....',
#  'Iam suriya annan big fan i like this song any malayalis here 2022',
#  'Fav song... ',
#  'My life......',
#  'കുഞ്ചാ കോബൊബനെ  മാത്രം ആരാധിച്ചു വന്ന മലയാളി സുന്ദരിമാർക്കു ഒരു സുന്ദരനെയും കിട്ടിയ നാളുകൾ\nSurya ️️️️️️',
#  'Daily vibe with Harris ',
#  '2022 still my fav ️from 🇱🇰',
#  'From \nPenney Un Mel pizhai...',
#  'Not a Tamilian, and yet this movie has left a mark on me even after a decade.',
#  'Harisssss magic ',
#  'What a handaome he is.... ഈ ഫിലിം നു ശേഷം ആണ് എനിക്ക് സൂര്യയോട് ഇത്രേം ഇഷ്ടം കൂടിയത്.... jyothika is really lucky... luv u suryaaaaaa',
#  'Harris music + hariharan voice = history',
#  'Nostu \nam a malayali who lives in hyderabad but sometimes tamil songs comes out my mouth bcz its in my mind all the tym \nbut none of my hyderabadi friends will understand this songs feeling ',
#  'i like to listen the song till my deth',
#  'Recently adicted ️',
#  'And  I love this movie song director Harris Jayaraj my favorite director is Harris jayaraj',
#  'നെഞ്ചുക്കുൾ പെയ്തിടും മാമഴൈ\nനീരുക്കുൾ മൂഴകിടും താമരൈ',
#  '1:30 to 1:50 surya eyes...\nLover boy surya  forever..the eyes & songs filled my college life ...even for single boys imagination angels..',
#  'Fav songever green',
#  '14 years ',
#  'Harris Jayaraj is wonderful musical is always best',
#  'Whhaa ! What a feeling...️',
#  'Who miss Harris Jayaraj who gave this kinda songs ?.... Love HJ',
#  'Feelgood one️️Harris sir & Hariharan sir nailed it️',
#  'Hariharan+Harris+ Surya ',
#  'Super song thaliva',
#  "My god what's soothing voice and instruments beat going on this song ️",
#  '2023 யாரெல்லாம் இந்த பாடலை கேட்கிறீர்கள் ?',
#  'This is like a wine.... Gets better with age ️',
#  'Still perfect in 2023, ,ഈ  സോങ് ആണ് ഞാൻ ഗിറ്റാർ പഠിക്കാൻ കാരണം ......ഒറിജിനൽ ഗിറ്റാർ വായിച്ചത്  "സ്റ്റീവ് vatz" , കൂടാതെ കാണിക്കുന്ന ഗിറ്റാർ  ക്ലോസപ്പ് ഷോട്സ് എല്ലാം സ്റ്റീവ് തന്നെ ..what a feel man  സ്റ്റീവ് നെ അറിയുന്നവർ  ലൈക് അടിച്ചിട് ',
#  'Vaaram aayiram is not only a movie. But also a journey towards the life of Surya.',
#  "it's a such a fantastic movie love all scene n song ",
#  'Varsham ethara kazhinjalum song nte freshness pokunilla ️️️',
#  'All Time favorite Songs ',
#  'ഒരു കടുത്ത വിജയ് ആരാധകൻ ആയ എന്റെ കൂട്ടുകാരന്റെ ഫോണിൽ ഇപ്പോഴും ഓടുന്ന സിനിമ ആണ് ഇത് ഇവിടെ ആണ് ഈ സിനിമയുടെ വിജയവും സൂര്യ എന്ന നടന്റെ കഴിവും നമ്മൾ എടുത്ത് പറയണ്ടത് ഒരു ഫാൻ എന്ന നിലക്ക് അഭിമാനം തോന്നുന്ന നിമിഷം',
#  'He is very cute super  iam from srilanka. My favourite actor ',
#  'Whenever I listen to this song, I feel like I am in a different world ',
#  'Indha paatuku national award laam kodukka maateenga\nVera edho edho paatukku poitu irukku ipoellam\nPonga pa unga award uh',
#  'Happy birthday Surya Anna ',
#  'My favourite lovely song',
#  "ഇറങ്ങിയ  സമയത്തു  ഈ പാട്ട് ഉണ്ടാക്കിയ ഒരു ഓളം വേറെ ലെവൽ ആയിരുന്നു.ഒരുത്തൻ ഗിറ്റാറും എടുത്ത് ഇറങ്ങിയാൽ തന്നെ അറിയാമായിരുന്നു 'നെഞ്ചുക്കുൾ പെയ്തിടും 'പാടാതെ പോവില്ലാന്നു. ഹൈസ്കൂൾ നൊസ്റ്റാൾജിയ",
#  "i love this song so much... watched this movie at my uncle's place until 2am at jabalpur  .... became fan of Surya...  n i loved this song Because the tune was so lovely....",
#  'Ethhu Shooperadah ',
#  'Love from 🇱🇰 ️',
#  'Viauals and frames are just awesome',
#  'Harris magic',
#  'Mixing quality-150/100\nActing-120/100\nBass-1000/100\nTune- .........infinity/100',
#  'The visuals are so beautiful ',
#  'Vera level feelings ️️️',
#  'Happy Birthday Harris Maams eh...8 Jan 2023',
#  '22k lots of Love Surya & Meghna ',
#  'ന്റെ മോനെ seen \U0001faf6',
#  '"என்னோடு வா வீடு வரைக்கும் என் வீட்டை பார் என்னை பிடிக்கும்\'\' இந்த வரியை சின்ன வயசுல முணுமுணுத்தது இன்னும் மறக்க முடியல',
#  'Harris jayaraj+surya=Heaven ',
#  'Thanku so much Harris for giving so much memorable and refreshing songs \nProud to be born in 90s ',
#  'I am a suriya fan',
#  'What a song. Hatts off you hariharan sir',
#  '23.57 PM 31th December 2022',
#  'ഹരീഷ് ജയരാജ്\u200c \nഗൗതം മേനോൻ \nസൂര്യ അണ്ണൻ ',
#  'ഒരുപാട് നാളുകൾ കാത്തിരുന്ന ശേഷം നാളെ ഞാൻ guitaar വാങ്ങാൻ പോവുകയാണ്.... അത്രക്കും ഇഷ്ട്ടം ആണ് ഈ song',
#  'One of the most heartfelt song I ever heard. Even im a Srilankan,I love the song and the movie also.I watched it more than 5 times and never get board .This song never gets old.Take a bow Harris Jayaraj and the production team',
#  'LOVE',
#  "I may not be anybody's fan, but a fan of music  Sarcasm reloaded ",
#  'Hariis jayaraj hats off....',
#  '2020 ൽ കാണാൻ എത്തിയവരുണ്ടാവുമല്ലോ അല്ലേ ! ️️',
#  'Still One of My fav \n\nThis movie inspired me lot and make me a diehard suriya fan ',
#  'Again and again !!️ always surya fan. GVM made this song beautiful and he bring the beauty of a women on screen in each frame !!',
#  'Sameera Reddy is so beautiful...',
#  'my favorite In tamil song',
#  '@2:07 i can see gvm in Surya well learnt from the director',
#  'ഹേറ്റേഴ്\u200cസ് ഇല്ലാത്ത സിനിമ. വിജയ് ഫാൻസ്\u200c പോലും ഇഷ്ടപെടുന്ന സൂര്യ അണ്ണന്റെ ഒരു മികച്ച സിനിമ.',
#  'I loved  this music   !',
#  'Harris jeyaraj music Vera level ',
#  'super song',
#  'Beautiful full song ',
#  'Best in the world my favourite song  love it',
#  'ഗൗതം മേനോൻ സർ.... ഹാരിസ് ജയരാജ്\u200c  ആഹാ അന്തസ് ',
#  '2024 now, 9 years back and still we remember each and every line of the song... that is the impact it has made..',
#  'Woow... Eththanai time kettalum vera level feeling... ',
#  'Harris️️️️️',
#  'Ini ethana paatu vanthalu intha feel tharathu ',
#  'Still',
#  '11 years of varanam ayiram ',
#  'Lots of love from a tamil speaking Marathi ',
#  'No one can replace suriya️',
#  'from  kerala',
#  'EVERRY TIME I LISTEN THIS SONG, I FEEL REBORN...THATS THE MAGIC OF THIS SONG...HARISS HATS OFF MAN...A LOT OF SCHOOL MEMMORIES TOO',
#  'So sweet song',
#  '5 years aayi..ennitum comment section eppozhum active .....',
#  'Forever Suriya ️ Harris jayaraj ️',
#  'Suriya annan ',
#  '2024',
#  '4.21 to 4.50 the best of music, visuals and dance! Harris on ',
#  'My fav',
#  'Any Malu suriya fans \nLike \nI am a Malayali \nSuriya annande katta fann ️️',
#  'Favorite forever',
#  'Hariharan sir voiceee next level ',
#  'Hariharan ',
#  'Whenever I will travel in the train, just relax enjoy the beauty of the lyrics, immediately sung in my inner  heart, wonderful lovely lyrics of legend Thamarai madam !\nHarris jeraj sir, lovely guitar BGM, feel the love moment ',
#  'Anything but the SUBTITLES.... they are not even close to the emotions this song Convey.... please do a proper translation.....',
#  'Guitar, Six Packs, Giving beloved women their respect and love they deserve rather than materializing. Surya and Gvm started the trend!',
#  "I've got addicted to this",
#  ':  Loveable Memories  :\n\nHarris Jayaraj Nailed it ',
#  'அமெரிக்கா ',
#  'Suriya ️',
#  'Harris jayaraj is  music king',
#  'ഇന്ന് വാരാണം ആയിരം ഇറങ്ങിയിട്ട് 12 വർക്ഷം ഞാൻ മാത്രമേ ഒള്ളോ ഇവിടെ ഈ പാട്ട് കേൽക്കാൻ വന്നത്',
#  'ഈ പടം കണ്ട് പട്ടാളത്തിൽ കേറിയ ഞാൻ ',
#  'This song has still the same freshness now..Harris sir ️',
#  'Surya anna',
#  "I can't believe this song was composed Harris Jayaraj",
#  'HARRIS JAYRAJ sir pls tell how only u could do these magic',
#  'சூர்யா\nസൂര്യ\nಸೂರ್ಯ\nసూర్య',
#  'தமிழின் இனிமையை ரசிக்கும் என் மல்லு சகோகளை கண்டால் பெருமையாக இருக்கிறது',
#  'All time favourite സൂര്യ',
#  'No: 1 music director Harris jeyaraj one & only',
#  'All my favorites ️',
#  'ROMANTIC',
#  'This song cannot be replaced forever! Amazing harrisjayaraj sir! GVM sir, SURIYA SIR!',
#  '"oh santhi santhi oh santhi" line hits different in this song and the other song ️️...love this song a lot..',
#  "it's been 13 year's \nbut still haven't regret to stop listening  for this album ",
#  'Surya  sir',
#  'Gautam vesu Deva Menon sir beautifully portrayed women and love story nailed it ',
#  'For me also bro ',
#  'Suriya deserved national award for this movie... \nHearing this song makes one fall in love.. ',
#  'Suriya is  my one and only fav actor... How handsome he is.. Tajmahal scenes are mind blowing...stunning Sameera',
#  'Always and my favourite!!',
#  'I am Vijay fan favourite is suriya️️',
#  'I dont understnd why people are going behind kpops and western songs these days...where as we have a dozen of songs like this which will take you into another world....songs like these are really unappreciated...kind of sad though....such a calming song',
#  'Best movie surya',
#  'ഈ പടം തിയേറ്ററിൽ പോയി ആസ്വദിക്കാൻ പറ്റാത്തവർ ആയിരിക്കും നമ്മളിൽ പലരും...',
#  '2023 still rocking ',
#  'Hariharan voice hits different ',
#  'DC to Sameera Reddyman ....Actor M.Prajeeth\nActress KeerthyRam\nWritten and directed By Gautham Vasudev Menon️sir as gvm chithappa family ......welcome first i invite uuuuu in shieffield homesir .....21.09.2004.',
#  'What! a feel...️ Throwback old memories  my love ️',
#  'Harris',
#  '2K kids - Pyaar prema Kadhal , OK kanmani\n80s kids - Mouna Raagam , Alaipayudhe\n90s kids - one and only Vaaranam Aayiram ️️',
#  'Love this vibe',
#  'Gorgeous song...',
#  'Singer  Hariharan + Devan Ekambram +  VV prasanna melting voice semma  Suriya  Sameera Reddy pair semma  நெஞ்சம் குள் பெயத்தும் மாமனழ நீர்குள் முழுகிடடும் தாமனர சட்டென்று மாறு வான்நினல பெண்னே உள்ள மேல் நீ இல்லாமல் பேர் ஆனல நெஞ்சில் வீசும் தாரினக பெண்னே நீ காஞ்னன பினழ நீ இல்லாமல் விசி தாரமினக ஒ சாந்தி சென்றாய் நீ தாண்டி ஏதோ ஒன்று என்ன இழக்க முக்கின் நுனி மர்மம் பேச்சு என்னோடு வா வீடு வரனவக்கும் தூக்கனள தூக்கி சென்றாய் உன்னன தாண்டி நீ சுட்டும் பூ ஒரு போதும் உதிராது கேட்காது காதல் இல்லை நீ இல்லை என்றாலே என் நெஞ்சம் தாங்காது நெஞ்குள் நீந்திடும் தாரினக ஒ சாந்தி ஏன் உயிர் நீ ஏந்தி இனி நீ தான் என் அந்தாதி பாடல் வரிகள் Lyrics ',
#  'Vaazhum naatkal aduthavarai manam noga seyyamal povomaga everyone resembles their families identical faces',
#  'Best ever Harris jayaraj',
#  'Haris jayaraj music king--\n1.minnale\n2.saami\n3.anniyan',
#  'Amazing Surya',
#  'still this song remains fresh like rain',
#  'Never ',
#  'Super song ',
#  'Surya love',
#  'ஹரிஸ் ஜெயராஜின் தரமான சம்பவங்களில் இதுவும் ஒன்று',
#  'Life long vibe Musics.............',
#  'ഈ പാട്ടിന് പ്രത്യേകതയുണ്ട്. അന്നും ഇന്നും എന്നും ഫ്രഷായും പുത്തൻ പോലെ തോന്നിക്കും️️️️',
#  'feelings is the love ',
#  'Vera level song Harris + Hariharan best song',
#  '2008 ஆம் ஆண்டு நான் +1 படிச்சிட்டு இருக்கேன் டெய்லி இசையருவி சேனல்ல போடுவாங்க இந்தப் பாடலை கேட்டுட்டு தான் நான் ஸ்கூலுக்கே போவேன் மறக்க முடியாத நினைவுகள்',
#  "this song is the reason why I'm a guitarist now ",
#  'Pure wine',
#  'Super song ',
#  'Lyrics ',
#  'One of the best movies ever made and one of the best songs ever too ',
#  'My amma favorite song',
#  'ഈ പാട്ട് ഞങ്ങൾ അങ്ങ് എടുക്കുവാ സൂര്യ അണ്ണാ ഉയിർ ',
#  'Iam here for listening steve. Rip legendary guitarist',
#  'Addiction to this song  recently yaaaa ',
#  'Im fan always surya',
#  'I keep falling for this song every time I hear ',
#  'I proud of Harris jayaraj sir',
#  'Harris Jayaraj ️\nSuriya ️\nGautham Vasudev menon️',
#  'This song is very pleasant ',
#  "I wish after many years my son/daughter could see this comment and know this is dad's favourite song ️",
#  'i llove u suryaa',
#  'This is a amazing  song....... ',
#  'Harris jayaraj ',
#  'Yov Harris eppoaya intha maathiri Oru comeback koduppa ?! ',
#  'Its 2024 still fresh.. Evergreen song...<3',
#  'All time favourite songs...',
#  'Kaali thenral️️️️️️️',
#  'My heart blushes while hearing this masterpiece. So much memories it brings back.',
#  'Just sitting infront of this Tower Park that..where Surya had danced...for this portion and Vibing to this   00:42  whenever I come here..',
#  'யாராவது வேறு மாநில அல்லது வேறு நாட்டவர்க்கு நம் பாடல் ஒன்றை பறிந்துரைக்க சொன்னால் என் மனதில் வரும் முதல் பாடல் இதுதான் ',
#  'Pure bliss to listen to even in 2023 ',
#  'The rhythm of Tamil ️...........',
#  'Thamarai u beauty ',
#  'Its surya birthday... its 2022 .here I came to listen this masterpiece once again ',
#  'Vaaranam ayiram',
#  'தமிழ் தாய் உங்களை  எப்பொழுதும் வாழ்த்தும்  தமிழனாக  இருப்பதே  பெருமையாக  கருதுகிறேன்',
#  'GVM forever ',
#  'Indha song ketkum bodhellam my scholl days niyabagam  varudhu I love this song',
#  'HARRIS JAYARAJ MAGIC ',
#  'Love from Sri Lanka 🇱🇰 ️',
#  '1st standard memories',
#  'Lyricist Thamarai Mam, wow.. " ennodu vaa veedu varaikkum, enn veettai paar ennai pidikkum". Ithaivida azhagaana proposal irukka mudiyaathu. Lots of love to Thamizh from Malayalam.',
#  'Always in love with this song ️!!Whenever I listen to this, it always bring back my school days',
#  'MASTERPIECE',
#  '....nenjukul peythidm mamathai',
#  'These lyrics have my heart',
#  'Surya ....(rolex)...fans like ',
#  'Really missing this type of movies from Surya !!!!',
#  'This Song Makes Different Feel',
#  'Nostalgia ',
#  'Veri nice song and heart touching song love from sri lanaka',
#  'What a song by Haris \nAnd extraordinary from SURYA ',
#  'Surya ',
#  'தமிழர் மலையாளிகளை பார்த்தாவது தமிழில் பதிவு செய்ய கற்று கொள்ள வேண்டும். அவர்களுக்கு ஆங்கிலம் தெரிந்து இருந்தாலும் மலையாலத்திலேயே பதிவிடுகிறார்கள் . வெறும் தமிழ் தமிழ் என்று உரக்க பேசினால் மட்டும் தமிழ் வளராது. தமிழை வெகுவாக பயன் படுத்துவது மூலமாகவே தமிழ் வளரும். தமிழர் என்று நாமும் பெருமை பட முடியும்.',
#  'Top 100 tamil songs la ithu irukum ️',
#  'Vera level song',
#  'So beautiful song',
#  "2am and suddenly remember this song  and it's raining outside ️ forever in love with this man and song️",
#  'Very nice songs Surya hansboy',
#  'വെറുതെ അല്ല സൂര്യയെ നടിപ്പിൻ നായകൻ എന്ന് വിളിക്കുന്നെ... \nIm big surya fan..  kerela',
#  'Favourite song ',
#  'Lovely lines️️',
#  'Still waiting to meet Lasika....from Hyderabad ',
#  'Always in our hearts surya ',
#  'Love you',
#  'ലോസ് എയ്ഞ്ചൽസ് ൽ വച്ച് സൂര്യ യുടെ കാമുകി മരിക്കുന്ന scene എത്രപേർക്ക് ഓർമയുണ്ട് ?\nഞാൻ സിനിമ ഒരൊറ്റതവണ മാത്രമേ കണ്ടുള്ളൂ... \nപക്ഷെ ഇപ്പോഴും ആ രംഗം മനസ്സിൽ തങ്ങി നിൽക്കുന്നു...',
#  'Love this song.....m a big fan of Suriya',
#  'One of my favourites during college days.. Surya is superstar',
#  'Hariharan magic',
#  "My friends recommended me to watch this movie long back but somehow I couldn't watch it then... Watched it today and I must say Surya's acting is top class... The way his life transforms from beginning to end...And this song is the highlight of the whole movie!! Sucha lovely song",
#  'Rolex',
#  '10 വർഷം കടന്നു പോയി ജീവിതത്തിലെ നല്ല നാളുകൾ.. കളമശ്ശേരി പോളി ടെക്നിക്കൽ ഹോസ്റ്റലിൽ ഞാനും എന്റെ ഫ്രണ്ട്സും കൂടി കേൾക്കാറുള്ള പാട്ട്.. radio mango club fm ഇതിലൊക്കെ ഈ പാട്ട് വരാൻ നോക്കി ഇരിക്കും... ശെരിക്കും miss ചെയ്യുന്നു... ഇപ്പൊ 10 വർഷങ്ങൾക്കിപ്പുറം എന്റെ മോന്റെ കൂടെ ഇരുന്നു ഈ പാട്ട് കേൾക്കുമ്പോ ശെരിക്കും വല്ലാതെ feel ചെയ്യുന്നു.. പോളിയും HMT JUNCTIONUM പിന്നെ എന്റെ ഫ്രണ്ട്\u200cസ് ശാരിക ഗായത്രി അശ്വതി അപർണ ജിംനാ... ',
#  'Currently addicted this song.... ',
#  'the song which made us crazy for years \nintha song ah parthittu guitar ah thookkittu suththanum nu ninaicha aayiram pearula naanum oruthan \ngood old days ',
#  '3:27 before nice line',
#  'Harris jayaraj na summa vaa️',
#  "Harry's jayaraj ️️",
#  '5:30 is the main handsome look and fame for suriya ',
#  'First love failure combo my fav\n1-Vaaranam ayiram.....major surya v/s megna\n2 -Sillinoru kadhal....Goutham v/s aishu\n3- thoovana thumbikal..... Jayakrishnan v/s clara',
#  '12 years and counting.. not a tamil.. but this song plays the strings of my heart every single time i hear it... just amazing.. just soulful',
#  'This movie all time favorite',
#  'This song is an emotion ️\u200d',
#  '3:47',
#  'ഹേറ്റേഴ്\u200cസ്നെ കൊണ്ട്\u200c പോലും കയ്യ് അടിപ്പിച്ച സൂര്യ,Gvm ,ഹാരിസ് ജയരാജ് മാജിക് അതായിരുന്നു വാരണം ആയിരം എത്ര കണ്ടാലും ഫ്രഷ്നസ് നഷ്ടപ്പെടാത്ത ഫിലിം',
#  'Still the best song in the world ',
#  'Whenever I hear the song just I fell love with him ️',
#  'My name is surya Narayanan i see your all movies i like it oh I know you name is suriya and your same like me and I am your biggest fan ',
#  "Through I have a very poor knowledge about the Tamil language I can sing this song. This is the best music album of Surya's career. The entire Sri Lanka is quite mad about this song.",
#  'நெஞ்சுக்குள் பெய்திடும் மாமழை',
#  'ഇത് പോലത്തെ പാട്ടുകൾ എന്താ ഇപ്പൊ ഇറങ്ങാതെ???  Wat a song ️️️',
#  'What a lovely nd melodious song .My hearty congratulations to the creators of this song',
#  "It's 2023 but still feels fresh️",
#  'This song get my remind my olden days 21-12-2022...10:58am',
#  '2022 still giving so much feeling ️heart touching film',
#  'GVM and his magical creation',
#  'എത്ര വർഷമായി കേൾക്കുന്നു ഇപ്പോഴും മടുക്കാത്ത ഗാനം',
#  'Surya is vere level in Romantic Songs.',
#  'Not understanding the song, but I love this song️and Surya is my fav actor️',
#  'Sema song',
#  'One of my favorite ️',
#  'Fav song ',
#  "Everyone's mother tougue is like honey for everyone. Tamil is my soul . காதலர்கள் கொண்டாடும் கண்ணியமான வரிகள்.  \nDon't hate anyone in the name of language. We all are music lovers.",
#  'Soo soothing ',
#  'Missing this type of Harris',
#  'Favorite ',
#  '13 years still my favorite ',
#  'Thalaivan Suriya ',
#  '2021ம் ஆண்டு இந்தப் பாடலைக் கேட்கிறவர்கள் ஒரு  போடுங்கள்',
#  'Still love this song  🇱🇰',
#  'what a movie and what an album. ',
#  'My favourite song️️️️️️️️️️️loves is beautifully ',
#  'I think beautiful dreamy songs that r close to our hearts stopped coming after vaaranam aayiram.. in search of more reality in films we missed this kind of songs with beautiful melody, lyrics and visuals that transported us to a more beautiful world.. i miss that era of arr and harris...',
#  'அன்பான  என் இனிய உறவுக்கு என் அன்பான இனிய காலை வணக்கம் அன்பான அன்புடன் அன்பே',
#  'My friend from India taught me this song in exchange I teach him Filipino religious songs in 2015. I just know of the melody. I do not exactly know what the lyrics meant but this song symbolises the beautiful friendship we have during our stay in Cebu. I always remember you in this song. Wherever you are, my love is with you.',
#  'Nil enru nee sonnal nilamal veesey   dum    peralai  kam  kalai wow really wonderful song cutest actress nice voice music  samma i love so much   ',
#  'Still very freshhh n remains fresh forever ',
#  'Surya',
#  'What a beauuuuuuuutiful song  ',
#  "Official Love Song of 90's Kids",
#  'Lockdown in Kerala\nAny Malayalees came here to hear this beautiful song ️️',
#  'All time fave️',
#  'One of my fav song forever ',
#  'Master piece of gautham and haaris',
#  'Favourite movie favourite song forever️',
#  'എല്ലാ ദിവസവും എന്നെ  പോലെ ഇത് കേൾക്കുന്നവർ ഉണ്ടോ ️',
#  'எத்தனை தடவை கேட்டாலும் சலிக்காத பாடல்,thanks for harris jeyaraj',
#  'ഇപ്പൊ കേട്ടാലും പുതിയ പാട്ട് കേൾക്കുന്ന ഫീൽ (ഹാരിസ്)',
#  'എന്താ ഒരു ഫീൽ....',
#  'Sweet',
#  'This movie is like stars in a sky with a beautiful full moon view ',
#  '4:21 ',
#  'നന്ദി ഹാരിസ് ജയരാജ് സർ, ഇതുപോലൊരു പാട്ട് തന്നതിന്.... ജീവിതത്തിൽ ഞാൻ ഏറ്റവും കൂടുതൽ കേട്ട പാട്ട്.... 12 വർഷങ്ങൾക്ക് ശേഷവും അതേ ഫീൽ',
#  'One of my favourite songs of all time  Surya',
#  'This was one my favs back then... I was listening to this on my Nokia express music phone on my KSRTC journey from Hassan to home... Good old days...',
#  'Nadipin nayakan ️️️',
#  'Tune of love',
#  'Thalaivaa',
#  'this song is heaven!!!! butterflies in the stomach hearing it everytime!!',
#  'ආදරෙයි ! ( love) from sri lanka',
#  'എന്തൊരു ഫീലാ ️️️',
#  'fav',
#  "It's too good. Till this day Vaaranam Aayiram rules",
#  'Wawwwwww',
#  'Lots of respect to the Malayali brothers for their love and affection towards Tamil and Tamil songs .',
#  'Miss this kind of songs... OG school days, unforgettable memories,...',
#  'Indha song ippa release aahi irundha 1billion thandum',
#  'After re_release 2023',
#  'still vibing ️',
#  'School padikum podhu Partha film...ippa job ku poren 2022...but song first time eppudi keatano appudeya fresh a irruku...',
#  'ഒരു കാലത്തു മലയാളികളുടേ മനസു കവർന്ന Tamil Sweet Romantic Movie & Song',
#  'Addiction to this blissful song',
#  "This time life is good that's Harris magic ",
#  'ennodu va veadu vaerikum en veaviti par ennai pudiku,',
#  'Nostalgic memories ',
#  'Harris jayraj - Surya ',
#  'സൂര്യ എന്ന നടനെ സുധാകൊങ്ങറ നമുക്ക് തിരിച്ചു തന്നു. നല്ല പടങ്ങൾ ചെയ്യൂ. നമ്മൾ മലയാളീസ് കൂടെ ഉണ്ടാകും.',
#  'Nenjukkul peithidum  lovebile song ']

# %%
len(Comments)
# Out:
# 1020

# %%
Upvote=driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
for i in Upvote:
    Upvotes.append(i.text)

# %%
len(Upvotes),Upvotes[:500]
# Out:
# (1020,
#  ['9.5K',
#   '3.4K',
#   '58',
#   '104',
#   '2.7K',
#   '55',
#   '10K',
#   '24',
#   '147',
#   '70',
#   '486',
#   '71',
#   '3.7K',
#   '104',
#   '274',
#   '262',
#   '41',
#   '17',
#   '1.8K',
#   '68',
#   '94',
#   '16',
#   '47',
#   '48',
#   '3.5K',
#   '434',
#   '32',
#   '58',
#   '9',
#   '23',
#   '2.8K',
#   '75',
#   '12',
#   '31',
#   '6',
#   '28',
#   '2K',
#   '8',
#   '11',
#   '7',
#   '7',
#   '9',
#   '773',
#   '4',
#   '10',
#   '25',
#   '15',
#   '4',
#   '748',
#   '3',
#   '9',
#   '7',
#   '397',
#   '20',
#   '1.6K',
#   '5',
#   '22',
#   '20',
#   '4',
#   '3',
#   '895',
#   '10',
#   '11',
#   '6',
#   '87',
#   '5',
#   '577',
#   '5',
#   '30',
#   '4',
#   '6',
#   '35',
#   '757',
#   '9',
#   '3',
#   '4',
#   '47',
#   '4',
#   '654',
#   '70',
#   '2',
#   '8',
#   '7',
#   '1.3K',
#   '12',
#   '1',
#   '4',
#   '9',
#   '58',
#   '2K',
#   '30',
#   '2',
#   '3',
#   '6',
#   '4',
#   '217',
#   '21',
#   '2',
#   '6',
#   '4',
#   '4',
#   '407',
#   '3',
#   '47',
#   '23',
#   '4',
#   '85',
#   '7.7K',
#   '3',
#   '3',
#   '6',
#   '5',
#   '7',
#   '2.3K',
#   '2',
#   '21',
#   '2',
#   '12',
#   '3',
#   '1.2K',
#   '7',
#   '12',
#   '5',
#   '3',
#   '5',
#   '426',
#   '16',
#   '17',
#   '4',
#   '2',
#   '3',
#   '3.4K',
#   '2',
#   '1',
#   '12',
#   '26',
#   '15',
#   '3.8K',
#   '1',
#   '2',
#   '2',
#   '3',
#   '2',
#   '494',
#   '10',
#   '3',
#   '4',
#   '4',
#   '2',
#   '3.7K',
#   '147',
#   '2',
#   '5',
#   '9',
#   '1',
#   '586',
#   '4',
#   '1',
#   '3',
#   '3',
#   '8',
#   '868',
#   '2',
#   '2',
#   '2',
#   '3',
#   '5',
#   '408',
#   '3',
#   '1',
#   '14',
#   '12',
#   '8',
#   '3',
#   '338',
#   '2',
#   '9',
#   '3',
#   '7',
#   '1',
#   '1.3K',
#   '11',
#   '2',
#   '23',
#   '4',
#   '4',
#   '1.1K',
#   '1',
#   '4',
#   '4',
#   '1',
#   '1',
#   '476',
#   '3',
#   '5',
#   '11',
#   '2',
#   '4',
#   '130',
#   '13',
#   '14',
#   '3',
#   '9',
#   '3',
#   '339',
#   '1',
#   '7',
#   '3',
#   '6',
#   '2',
#   '167',
#   '6',
#   '2',
#   '6',
#   '4',
#   '2',
#   '341',
#   '7',
#   '5',
#   '1',
#   '12',
#   '15',
#   '816',
#   '',
#   '12',
#   '7',
#   '1',
#   '9',
#   '126',
#   '2',
#   '20',
#   '2',
#   '3',
#   '4',
#   '271',
#   '11',
#   '1',
#   '2',
#   '5',
#   '2',
#   '610',
#   '3',
#   '4',
#   '2',
#   '4',
#   '1',
#   '208',
#   '5',
#   '2',
#   '5',
#   '5',
#   '4',
#   '343',
#   '1',
#   '24',
#   '3',
#   '11',
#   '2',
#   '2.6K',
#   '22',
#   '5',
#   '3',
#   '4',
#   '3',
#   '888',
#   '3',
#   '3',
#   '7',
#   '3',
#   '3',
#   '172',
#   '2',
#   '3',
#   '2',
#   '1',
#   '2',
#   '1K',
#   '1',
#   '12',
#   '3',
#   '9',
#   '2',
#   '440',
#   '1',
#   '2',
#   '5',
#   '3',
#   '2',
#   '556',
#   '2',
#   '2',
#   '1',
#   '10',
#   '5',
#   '309',
#   '6',
#   '6',
#   '1',
#   '1',
#   '3',
#   '441',
#   '1',
#   '8',
#   '3',
#   '2',
#   '1',
#   '735',
#   '4',
#   '10',
#   '1',
#   '5',
#   '2',
#   '417',
#   '3',
#   '29',
#   '1',
#   '1',
#   '3',
#   '125',
#   '1',
#   '2',
#   '5',
#   '15',
#   '2',
#   '1.6K',
#   '3',
#   '4',
#   '2',
#   '5',
#   '3',
#   '1.1K',
#   '1',
#   '1',
#   '3',
#   '1',
#   '2',
#   '1.6K',
#   '1',
#   '2',
#   '2',
#   '3',
#   '2',
#   '189',
#   '2',
#   '6',
#   '1',
#   '1',
#   '4',
#   '1.1K',
#   '3',
#   '2',
#   '4',
#   '9',
#   '13',
#   '203',
#   '1',
#   '2',
#   '4',
#   '5',
#   '3',
#   '197',
#   '8',
#   '4',
#   '2',
#   '4',
#   '2',
#   '234',
#   '1',
#   '2',
#   '1',
#   '15',
#   '5',
#   '448',
#   '6',
#   '8',
#   '1',
#   '7',
#   '1',
#   '176',
#   '2',
#   '1',
#   '1',
#   '1',
#   '5',
#   '98',
#   '4',
#   '2',
#   '2',
#   '1',
#   '7',
#   '747',
#   '4',
#   '2',
#   '2',
#   '1',
#   '2',
#   '811',
#   '',
#   '1',
#   '',
#   '35',
#   '1',
#   '483',
#   '3',
#   '1',
#   '1',
#   '4',
#   '1',
#   '295',
#   '2',
#   '3',
#   '1',
#   '16',
#   '3',
#   '252',
#   '3',
#   '1',
#   '3',
#   '',
#   '1',
#   '65',
#   '1',
#   '3',
#   '3',
#   '7',
#   '2',
#   '159',
#   '5',
#   '2',
#   '1',
#   '9',
#   '',
#   '575',
#   '3',
#   '22',
#   '15',
#   '11',
#   '',
#   '148',
#   '1',
#   '5',
#   '',
#   '3',
#   '2',
#   '344',
#   '1',
#   '2',
#   '2',
#   '5',
#   '1',
#   '116',
#   '2',
#   '1',
#   '2',
#   '4',
#   '1',
#   '266',
#   '1',
#   '3',
#   '1',
#   '2',
#   '',
#   '508',
#   '4',
#   '2',
#   '1',
#   '2',
#   '9',
#   '185',
#   '1',
#   '',
#   '',
#   '7',
#   '1',
#   '197',
#   '2',
#   '3',
#   '3',
#   '1',
#   '2',
#   '770',
#   '1',
#   '1',
#   '2',
#   '1',
#   '4',
#   '1.9K',
#   '5',
#   '2',
#   '4',
#   '1',
#   '2',
#   '492',
#   '3',
#   '1',
#   '2',
#   '2',
#   '1',
#   '149',
#   ''])

# %%
time=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')
for i in time:
    Time.append(i.text)

# %%
len(Time),Time[:500]
# Out:
# (1020,
#  ['3 years ago (edited)',
#   '1 year ago',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '1 month ago',
#   '3 years ago',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '10 months ago',
#   '1 year ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '10 months ago',
#   '3 years ago',
#   '1 year ago (edited)',
#   '1 year ago',
#   '4 months ago',
#   '1 year ago',
#   '1 year ago (edited)',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '9 months ago',
#   '2 months ago',
#   '1 year ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '8 months ago',
#   '1 year ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '2 years ago',
#   '1 year ago',
#   '11 months ago',
#   '1 year ago',
#   '1 year ago (edited)',
#   '2 months ago',
#   '3 years ago',
#   '8 months ago',
#   '1 year ago',
#   '7 months ago',
#   '1 year ago',
#   '2 months ago',
#   '3 years ago',
#   '1 year ago',
#   '1 month ago',
#   '10 months ago',
#   '5 months ago',
#   '11 months ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '10 months ago',
#   '6 months ago',
#   '3 years ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '1 month ago',
#   '11 months ago',
#   '1 year ago',
#   '1 year ago',
#   '9 months ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '4 years ago',
#   '4 weeks ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago (edited)',
#   '8 months ago',
#   '8 months ago',
#   '1 month ago',
#   '1 year ago (edited)',
#   '2 months ago',
#   '3 years ago',
#   '2 months ago',
#   '1 year ago',
#   '1 year ago',
#   '2 weeks ago',
#   '3 months ago',
#   '3 years ago (edited)',
#   '7 months ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '6 months ago',
#   '3 years ago',
#   '5 months ago',
#   '1 year ago',
#   '9 months ago',
#   '1 year ago (edited)',
#   '6 months ago',
#   '2 years ago',
#   '8 months ago',
#   '6 months ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '2 years ago (edited)',
#   '7 months ago',
#   '1 year ago (edited)',
#   '2 months ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago (edited)',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '6 months ago',
#   '1 month ago',
#   '5 years ago',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '2 years ago',
#   '1 year ago',
#   '1 year ago',
#   '3 months ago',
#   '1 year ago',
#   '1 month ago',
#   '2 years ago (edited)',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '9 months ago',
#   '4 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '2 months ago',
#   '2 years ago',
#   '1 year ago',
#   '1 year ago',
#   '7 months ago',
#   '8 months ago',
#   '1 year ago',
#   '2 years ago',
#   '10 months ago',
#   '5 months ago',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '10 months ago',
#   '1 year ago',
#   '9 months ago',
#   '1 year ago',
#   '1 year ago',
#   '1 month ago',
#   '3 years ago',
#   '1 year ago',
#   '4 weeks ago',
#   '1 year ago',
#   '4 weeks ago',
#   '1 year ago',
#   '3 years ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '2 years ago',
#   '4 months ago',
#   '1 year ago',
#   '1 year ago',
#   '4 months ago',
#   '1 year ago',
#   '3 years ago',
#   '6 months ago',
#   '1 year ago (edited)',
#   '1 year ago',
#   '2 months ago',
#   '1 year ago',
#   '2 years ago',
#   '1 year ago',
#   '1 year ago',
#   '2 months ago',
#   '11 months ago',
#   '1 year ago',
#   '3 years ago',
#   '4 days ago',
#   '4 months ago',
#   '2 months ago',
#   '1 year ago',
#   '7 months ago',
#   '3 years ago',
#   '5 months ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '4 years ago',
#   '1 year ago',
#   '8 months ago',
#   '1 year ago',
#   '1 year ago (edited)',
#   '11 months ago',
#   '5 years ago',
#   '1 year ago',
#   '3 months ago',
#   '1 year ago',
#   '1 year ago (edited)',
#   '1 year ago',
#   '3 years ago (edited)',
#   '1 year ago (edited)',
#   '1 year ago',
#   '2 months ago (edited)',
#   '1 year ago',
#   '1 month ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '2 months ago',
#   '1 year ago',
#   '9 months ago',
#   '3 years ago (edited)',
#   '1 month ago',
#   '10 months ago',
#   '1 year ago (edited)',
#   '1 year ago',
#   '4 months ago',
#   '3 years ago (edited)',
#   '10 months ago',
#   '2 weeks ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '2 years ago',
#   '9 months ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '4 years ago',
#   '9 months ago',
#   '1 year ago',
#   '11 months ago',
#   '1 year ago',
#   '10 months ago',
#   '4 years ago',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '10 months ago',
#   '5 months ago',
#   '3 years ago',
#   '8 days ago',
#   '1 year ago',
#   '1 year ago',
#   '6 months ago',
#   '1 month ago',
#   '4 years ago',
#   '1 year ago',
#   '1 year ago',
#   '11 months ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '2 weeks ago',
#   '6 months ago',
#   '1 year ago',
#   '3 years ago (edited)',
#   '2 months ago',
#   '7 months ago',
#   '1 year ago',
#   '6 months ago',
#   '6 months ago (edited)',
#   '2 years ago',
#   '1 year ago',
#   '10 months ago',
#   '6 months ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '5 months ago',
#   '1 year ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '4 years ago',
#   '1 year ago',
#   '1 year ago',
#   '2 months ago (edited)',
#   '1 year ago',
#   '11 months ago',
#   '2 years ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '5 months ago',
#   '9 months ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '6 months ago',
#   '4 months ago',
#   '1 year ago',
#   '4 years ago',
#   '7 months ago',
#   '1 year ago',
#   '3 months ago',
#   '1 year ago',
#   '1 year ago',
#   '4 years ago',
#   '2 weeks ago',
#   '1 year ago',
#   '3 months ago (edited)',
#   '1 year ago',
#   '7 months ago',
#   '2 years ago (edited)',
#   '1 year ago',
#   '7 days ago',
#   '2 months ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '1 year ago',
#   '8 months ago',
#   '5 months ago',
#   '1 year ago',
#   '1 year ago',
#   '4 years ago',
#   '1 year ago',
#   '11 months ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '10 months ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '2 years ago',
#   '1 year ago',
#   '9 months ago (edited)',
#   '2 months ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago (edited)',
#   '2 years ago',
#   '7 months ago',
#   '1 year ago',
#   '4 months ago',
#   '1 year ago',
#   '8 days ago',
#   '2 years ago',
#   '9 months ago',
#   '1 year ago',
#   '3 weeks ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago (edited)',
#   '1 year ago',
#   '1 year ago',
#   '11 months ago',
#   '1 year ago',
#   '1 year ago',
#   '5 years ago',
#   '1 year ago',
#   '4 months ago',
#   '1 year ago',
#   '1 year ago',
#   '6 months ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 month ago',
#   '1 year ago',
#   '6 months ago',
#   '4 years ago',
#   '1 year ago',
#   '1 year ago',
#   '9 months ago',
#   '1 year ago',
#   '1 year ago',
#   '4 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '10 months ago',
#   '2 years ago',
#   '1 year ago (edited)',
#   '1 month ago',
#   '11 months ago',
#   '1 year ago',
#   '1 month ago',
#   '3 years ago',
#   '7 months ago',
#   '9 months ago',
#   '5 months ago',
#   '6 months ago',
#   '4 months ago',
#   '4 years ago',
#   '1 year ago',
#   '8 months ago',
#   '1 year ago',
#   '1 year ago',
#   '2 months ago',
#   '3 years ago',
#   '1 year ago',
#   '9 months ago',
#   '9 months ago',
#   '1 year ago',
#   '11 months ago',
#   '3 years ago',
#   '6 months ago',
#   '1 year ago',
#   '11 months ago',
#   '1 year ago',
#   '1 year ago',
#   '3 years ago',
#   '5 months ago',
#   '3 months ago',
#   '1 year ago',
#   '9 months ago',
#   '10 months ago',
#   '5 years ago',
#   '1 year ago',
#   '1 year ago',
#   '7 months ago',
#   '11 months ago',
#   '4 days ago',
#   '2 years ago',
#   '1 year ago',
#   '1 month ago',
#   '10 months ago',
#   '1 year ago',
#   '6 months ago',
#   '4 years ago',
#   '9 months ago',
#   '1 year ago',
#   '1 year ago',
#   '5 months ago',
#   '3 months ago',
#   '4 years ago',
#   '10 months ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '10 months ago',
#   '2 years ago',
#   '1 year ago',
#   '7 months ago',
#   '1 year ago',
#   '10 months ago',
#   '1 year ago',
#   '3 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 month ago',
#   '1 year ago',
#   '1 year ago',
#   '4 years ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '1 year ago',
#   '7 months ago',
#   '3 years ago',
#   '1 year ago'])

# %%
Yt=pd.DataFrame({'Comments':Comments[:500],'Upvotes':Upvotes[:500],'Time':Time[:500]})
Yt
# Out:
#                                               Comments Upvotes  \
# 0    Everytime i travel by train i expect i will me...    9.5K
# 1    ഈ പടം റിലീസ് ആയിട്ട് 13 വർഷം കഴിഞ്ഞു, ഇപ്പോഴും...    3.4K
# 2    அது எப்படி திமிங்கலம் ஒரு படத்துல எல்லா பாட்டு...      58
# 3    ചുരുക്കം ചില പാട്ടുകൾ മാത്രമേ ആദ്യം കേൾക്കുമ്പ...     104
# 4    Vaaranam Aayiram is not just a movie, it's an ...    2.7K
# ..                                                 ...     ...
# 495  ennodu va veadu vaerikum en veaviti par ennai ...       2
# 496                                Nostalgic memories        2
# 497                             Harris jayraj - Surya        1
# 498  സൂര്യ എന്ന നടനെ സുധാകൊങ്ങറ നമുക്ക് തിരിച്ചു തന...     149
# 499                Nenjukkul peithidum  lovebile song
#
#                      Time
# 0    3 years ago (edited)
# 1              1 year ago
# 2             1 month ago
# 3              1 year ago
# 4              1 year ago
# ..                    ...
# 495            1 year ago
# 496            1 year ago
# 497          7 months ago
# 498           3 years ago
# 499            1 year ago
#
# [500 rows x 3 columns]

# %% [markdown]
# # Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
driver=webdriver.Chrome()
driver.get('https://www.amazon.in/')

# %%
inputU = input('please enter product here--->')
# Out:
# please enter product here--->Guitars

# %%
search_bar = driver.find_element(By.XPATH,'//*[@id="twotabsearchtextbox"]')
search_bar.send_keys(inputU)
search_button = driver.find_element(By.XPATH,'//*[@id="nav-search-submit-button"]')
search_button.click()

# %%
productName=[]

# %%
PName=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']")
for i in PName:
    if i.text is None :
        productName.append("--") 
    else:
        productName.append(i.text)
print(len(productName),productName)
# Out:
# 68 ['Kadence rosewood Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set Of Strings, Strap, Picks And Bag (Black EQ, Electric Acoustic)', 'Kadence Frontier guitar with Online Guitar learning course , Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)', 'Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo (Black Spruce Wood)', 'Henrix 38C 38 Inch Cutaway Acoustic Guitar With Dual Action Truss Rod, Gigbag, Picks, String Set, String Winder, Strap, Polishing Cloth & Ebook - Black', 'Yamaha F280 Acoustic Rosewood Guitar (Natural, Beige)', 'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black', 'Kadence rosewood Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set Of Strings, Strap, Picks And Bag (Black EQ, Electric Acoustic)', 'Kadence Frontier guitar with Online Guitar learning course , Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)', 'Kadence rosewood Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set Of Strings, Strap, Picks And Bag (Black EQ, Electric Acoustic)', 'BLUEBERRY B-38C, Acoustic Guitar Kit with Bag, Strap, One Pack Strings And 2 Picks - 38 Inch (Black)', '', 'Juarez Lindenwood Acoustic Guitar Kit, 38 Inches Cutaway, 38C With Bag, Strings, Pick And Strap, 3TS Sunburst', 'Intern INT-38C Right hand Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black, small', 'Henrix 38C 38 Inch Cutaway Acoustic Guitar With Dual Action Truss Rod, Gigbag, Picks, String Set, String Winder, Strap, Polishing Cloth & Ebook - Black', 'YAMAHA FS80C BLACK CONCERT CUTAWAY GUITAR', 'Medellin 38” Acoustic Guitar with (free learning course), Matt finish, Picks (Black)', 'Intern 38C Ebony Wood Cutaway Design Acoustic Guitar with Picks And Carry Bag (Black)', 'Intern INT-38C Acoustic Guitar Kit (Purple)', 'Yamaha 22.8 Inches Merantiwood Classical Guitar C40//02 (Brown)', 'Vault RG1 Soloist Premium Electric Guitar- Transparent Blue', 'Yamaha F280 Acoustic Guitar, Tobacco Brown Sunburst', 'YAMAHA F310, 6-Strings Rose Wood Acoustic Guitar, Natural', 'Yamaha FSX80C Semi acoustic cutaway guitar (natural)', 'YAMAHA FS80C NATURAL CONCERT CUTAWAY GUITAR', 'MOCKING BIRD 38 Inch Acoustic Guitar for Beginners Musical Instruments For Adults premium kit wood curved cutaway design Guitar Accessories with string & 5 picks & bag for beige (Sunburst Matte)', 'PERLMAN Paper Guitar Fretboard, Fingerboard Self-Adhesive Stickers, Decals Tool For Learner Or Beginner', 'ROCKON 41 INCHES ACOUSTIC GUITAR WITH HARD THERMOCOL CASE', 'Samara SA39CE CS 39" Cutaway Electro-Acoustic Guitar', 'Kadence Frontier Series, Acoustic Guitar With/Wihtout EQ Die Cast Keys Combo (Bag,strap,strings and 3 picks) (Natural, Semi/Electro Acoustic)', 'Fender Squier 39 Inch 6 String Cutaway Acoustic Guitar Hardwood Fretboard-Natural SA-135C', 'Cort SFX-MEM Electro Acoustic Guitar - Open Pore, Mahogany, SFXMEMOP (SFXMEMOP)', 'Yamaha FS100C Acoustic Guitar, Black', 'Hovner 215 Black F-Cut Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks By K-Retail', 'Revel 38 Inches Cutaway Design Acoustic Guitar with Carry bag and Plectrums. Great tone and Beginner/Learners standard size configuration for all age groups (Black)', 'Epiphone SG Muse Electric Guitar - Pearl White Metallic', 'Juarez JRZ38C/3TSNA Acoustic Guitar, 38 Inch Cutaway, 3TS Sunburst', 'Yamaha C40M Classical Guitar, Sprucewood (Brown)', 'Fender Acoustic Guitar Dreadnought CD60 V3 Black 970110506', 'Kadence Astro Man Electric Guitar, 21 FRETS, H- S - S PICK UPS Walnut Top with Alder wood Back and Sides With Picks, Cable, Strap, Bag, Strings and Amplifier', 'Fender Acoustic Guitar Dreadnought CD60 V3 Natural 970110521', 'Vault EA20 Guitar Kit with Learn to Play Ebook, Bag, Strings, Straps, Picks, String winder & Polishing Clo ...

# %% [markdown]
# # In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "BrandName", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and“Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
start_page = 0
end_page = 3
urls = []
for page in range(start_page,end_page+1):
    try:
        page_urls = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-no-outline"]')
        
       
        for url in page_urls:
            url = url.get_attribute('href')    
            if url[0:4]=='http':                
                urls.append(url)               
        print("Product urls of page {} has been scraped.".format(page+1))
        
       
        nxt_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')                                           
        nxt_button.click()                                                    
        time.sleep(5)                                                         
            
    except StaleElementReferenceException as e:             
        print("Stale Exception")
        next_page = nxt_button.get_attribute('href')        
        driver.get(next_page)
# Out:
# Product urls of page 1 has been scraped.
# Product urls of page 2 has been scraped.
# Product urls of page 3 has been scraped.
# Product urls of page 4 has been scraped.

# %%
prod_dict = {}
prod_dict['Brand']=[]
prod_dict['Name']=[]
prod_dict['Rating']=[]
prod_dict['No. of ratings']=[]
prod_dict['Price']=[]
prod_dict['Return/Exchange']=[]
prod_dict['Expected Delivery']=[] 
prod_dict['Availability']=[]
prod_dict['Other Details']=[]
prod_dict['URL']=[]

# %%
for url in urls[:4]:
    driver.get(url)                                                        # Loading the webpage by url
    print("Scraping URL = ", url)
    #time.sleep(2)
    
    try:
        brand = driver.find_element(By.XPATH,'//a[@id="bylineInfo"]')      # Extracting Brand from xpath
        prod_dict['Brand'].append(brand.text)
    except NoSuchElementException:
        prod_dict['Brand'].append('-')
    
    try:
        name = driver.find_element(By.XPATH,'//h1[@id="title"]/span')      # Extracting Name from xpath
        prod_dict['Name'].append(name.text)
    except NoSuchElementException:
        prod_dict['Name'].append('-')
    
    try:
        rating = driver.find_element(By.XPATH,'//span[@id="acrPopover"]')  # Extracting Ratings from xpath
        prod_dict['Rating'].append(rating.get_attribute("title"))
    except NoSuchElementException:
        prod_dict['Rating'].append('-')
    
    try:
        n_rating = driver.find_element(By.XPATH,'//a[@id="acrCustomerReviewLink"]/span')     # Extracting no. of Ratings from xpath
        prod_dict['No. of ratings'].append(n_rating.text)
    except NoSuchElementException:
        prod_dict['No. of ratings'].append('-')
    
    try:
        price = driver.find_element(By.XPATH,'//span[@class="a-price aok-align-center reinventPricePriceToPayMargin priceToPay"]')            # Extracting Price from xpath
        prod_dict['Price'].append(price.text)
    except NoSuchElementException:
        prod_dict['Price'].append('-')
    try:                                                                                     # Extracting Return/Exchange policy from xpath
        ret = driver.find_element(By.XPATH,'//div[@data-name="RETURNS_POLICY"]/span/div[2]/a')
        prod_dict['Return/Exchange'].append(ret.text)
    except NoSuchElementException:
        prod_dict['Return/Exchange'].append('-')
    try:
        delivry = driver.find_element(By.XPATH,'//div[@id="ddmDeliveryMessage"]/b')         # Extracting Expected Delivery from xpath
        prod_dict['Expected Delivery'].append(delivry.text)
    except NoSuchElementException:
        prod_dict['Expected Delivery'].append('-')
    
    try:
        avl = driver.find_element(By.XPATH,'//div[@id="availability"]/span')                # Extracting Availability from xpath
        prod_dict['Availability'].append(avl.text)
    except NoSuchElementException:
        prod_dict['Availability'].append('-')
    
    try:                                                                                    # Extracting Other Details from xpath
        dtls = driver.find_element(By.XPATH,'//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')
        prod_dict['Other Details'].append('  ||  '.join(dtls.text.split('\n')))
    except NoSuchElementException:
        prod_dict['Other Details'].append('-')
    
    prod_dict['URL'].append(url)                                                            # Saving url
    time.sleep(2)
# Out:
# Scraping URL =  https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0MTAxMjYzMDQ5MzQ1MDQwOjE3MDc1NDI4MTk6c3BfYXRmOjMwMDAxNTUzNzk3OTIzMjo6MDo6&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB078GTJP5Y%2Fref%3Dsr_1_1_sspa%3Fkeywords%3DGuitars%26qid%3D1707542819%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# Scraping URL =  https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0MTAxMjYzMDQ5MzQ1MDQwOjE3MDc1NDI4MTk6c3BfYXRmOjMwMDAxNTUwODk1NDEzMjo6MDo6&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_2_sspa%3Fkeywords%3DGuitars%26qid%3D1707542819%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# Scraping URL =  https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0MTAxMjYzMDQ5MzQ1MDQwOjE3MDc1NDI4MTk6c3BfYXRmOjIwMDU3MTkzMDU2MjA0OjowOjo&url=%2FKadence-Slowhand-Premium-Acoustic-Instrument%2Fdp%2FB077SZ667X%2Fref%3Dsr_1_3_sspa%3Fkeywords%3DGuitars%26qid%3D1707542819%26sr%3D8-3-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# Scraping URL =  https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0MTAxMjYzMDQ5MzQ1MDQwOjE3MDc1NDI4MTk6c3BfYXRmOjIwMDg4NDY1ODE5NDA0OjowOjo&url=%2FHenrix-Acoustic-Guitar-Die-cast-Dual-action%2Fdp%2FB07VNDW6QF%2Fref%3Dsr_1_4_sspa%3Fkeywords%3DGuitars%26qid%3D1707542819%26sr%3D8-4-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1

# %%
prod_df = pd.DataFrame.from_dict(prod_dict)
prod_df
# Out:
#                      Brand                                               Name  \
# 0  Visit the Kadence Store  Kadence rosewood Guitar Frontier Series, Elect...
# 1  Visit the Kadence Store  Kadence Frontier guitar with Online Guitar lea...
# 2  Visit the Kadence Store  Kadence Slowhand Premium Jumbo Semi Acoustic G...
# 3   Visit the Henrix Store  Henrix 38C 38 Inch Cutaway Acoustic Guitar Wit...
# 4  Visit the Kadence Store  Kadence rosewood Guitar Frontier Series, Elect...
# 5  Visit the Kadence Store  Kadence Frontier guitar with Online Guitar lea...
# 6  Visit the Kadence Store  Kadence Slowhand Premium Jumbo Semi Acoustic G...
# 7   Visit the Henrix Store  Henrix 38C 38 Inch Cutaway Acoustic Guitar Wit...
#
#                Rating No. of ratings   Price Return/Exchange  \
# 0  4.0 out of 5 stars  1,158 ratings       -               -
# 1  4.0 out of 5 stars  3,094 ratings       -               -
# 2  4.0 out of 5 stars    650 ratings       -               -
# 3  3.8 out of 5 stars  2,160 ratings       -               -
# 4  4.0 out of 5 stars  1,158 ratings  ₹5,499               -
# 5  4.0 out of 5 stars  3,094 ratings  ₹4,999               -
# 6  4.0 out of 5 stars    650 ratings  ₹9,999               -
# 7  3.8 out of 5 stars  2,160 ratings  ₹3,099               -
#
#   Expected Delivery Availability  \
# 0                 -     In stock
# 1                 -     In stock
# 2                 -     In stock
# 3                 -     In stock
# 4                 -     In stock
# 5                 -     In stock
# 6                 -     In stock
# 7                 -     In stock
#
#                                        Other Details  \
# 0  ★ Design - The High Gloss finish, Simple head ...
# 1  ★ Design - The High Gloss finish, Simple head ...
# 2  ACOUSTIC-ELECTRIC GUITAR: Kadence Slowhand sem...
# 3  Dual Action Truss Rod : Henrix 38C comes with ...
# 4  ★ Design - The High Gloss finish, Simple head ...
# 5  ★ Design - The High Gloss finish, Simple head ...
# 6  ACOUSTIC-ELECTRIC GUITAR: Kadence Slowhand sem...
# 7  Dual Action Truss Rod : Henrix 38C comes with ...
#
#                                                  URL
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 5  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 6  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 7  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...

# %% [markdown]
# # Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome()
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
Brands=[]
Products_Description=[]
Specification=[]
Price=[]

# %%
br=driver.find_elements(By.XPATH,"//h3[@class='font130 mt0 mb10 mobilesblockdisplay ']")
for i in br:
   
    Brands.append(str(i.text).replace("\n",""))
Brands
# Out:
# ['HP Omen 17-ck2008TX 13th Gen Core i7-13700HX',
#  'MSI GT77 Titan 12UHS-054IN 12th Gen Core i9-12900HX',
#  'Lenovo Legion 5i Pro 12th Gen Core i7-12700H (82RF00E1IN)',
#  'ASUS ROG Strix Scar 18 G834JZ-N5041WS 13th Gen Core i9-13980HX',
#  'Acer Predator Helios Neo 16 13th Gen Core i7-13700HX (PHN16-71)',
#  'ASUS ROG Zephyrus G14 Ryzen 9-6900HS (GA402RJZ-L4136WS)',
#  'MSI Cyborg 15 12th Gen Core i7-12650H (A12VF-205IN)']

# %%
sp=driver.find_elements(By.XPATH,"//div[@class='rh_gr_middle_desc']")
for i in sp:
   
    Specification.append(str(i.text).replace("\n",""))
Specification
# Out:
# ['Operating System:Windows 11 HomeDisplay Size :17.3Resolution :2560 x 1440Processor :13th Gen Intel Core i7-13700HX',
#  '',
#  'Operating System:Windows 11 HomeDisplay Size :16Resolution :2560 x 1600Processor :12th Gen Intel Core i7-12700H',
#  '',
#  'Operating System:Windows 11 HomeDisplay Size :16Resolution :2560 x 1600Processor :13th Gen Intel Core i7-13700HX',
#  '',
#  '']

# %%
pri=driver.find_elements(By.XPATH,"//div[@class='cegg-price cegg-price-color cegg-price-instock']")
for i in pri:
   
    Price.append(str(i.text).replace("\n",""))
Price
# Out:
# ['Rs. 159,990',
#  'Rs. 118,300',
#  'Rs. 9,499',
#  'Rs. 14,990',
#  'Rs. 44,999',
#  'Rs. 59,999',
#  'Rs. 92,999']

# %%
lt=pd.DataFrame({'Brands':Brands,'Specification':Specification,'Price':Price})

# %%
lt
# Out:
#                                               Brands  \
# 0       HP Omen 17-ck2008TX 13th Gen Core i7-13700HX
# 1  MSI GT77 Titan 12UHS-054IN 12th Gen Core i9-12...
# 2  Lenovo Legion 5i Pro 12th Gen Core i7-12700H (...
# 3  ASUS ROG Strix Scar 18 G834JZ-N5041WS 13th Gen...
# 4  Acer Predator Helios Neo 16 13th Gen Core i7-1...
# 5  ASUS ROG Zephyrus G14 Ryzen 9-6900HS (GA402RJZ...
# 6  MSI Cyborg 15 12th Gen Core i7-12650H (A12VF-2...
#
#                                        Specification        Price
# 0  Operating System:Windows 11 HomeDisplay Size :...  Rs. 159,990
# 1                                                     Rs. 118,300
# 2  Operating System:Windows 11 HomeDisplay Size :...    Rs. 9,499
# 3                                                      Rs. 14,990
# 4  Operating System:Windows 11 HomeDisplay Size :...   Rs. 44,999
# 5                                                      Rs. 59,999
# 6                                                      Rs. 92,999
